# %% [markdown]
# # FIT5202 - Data processing for Big data
# ## Semester 2, 2020
# ***
#
# # Assignment 1 - Analyzing Road Crash Data
# <br>
#
# **Background**
#
# The Department of Planning, Transport and Infrastructure (DPTI), South Australia collects data from various road crashes for further analysis in an endeavor to improve road safety. Over time, the data increases in size; the increase in the number of vehicles also contributes to huge amounts of data. As we look across multiple states, we can imagine a rather large set of data. Here, we want to employ various operations on the dataset using Spark to answer different queries.<br><br>
# **Required Datasets:**<br>
# Two datasets: Unit and Crash datasets from year 2015 - 2019

# %% [markdown]
# ## Student Information
# ***
# Name: <br>
# <span style="color: brown">Abhilash Anil Kale</span><br><br>
# Student number: <br>
# <span style="color: brown">30254140</span><br><br>
# Tutorial number:<br>
# <span style="color: brown">16-P2</span><br><br>
# Tutors:<br>
# <span style="color: brown">Prajwol Sangat & Neha Jain</span><br><br>
# Environment:<br>
# <span style="color: brown">Python *3.8.2* and Spark *3.0* </span>

# %% [markdown]
# # Part A: Working with RDDs and DataFrames

# %% [markdown]
# ## Table of Contents
#
# * [1. Working with RDD](#1)
#     * [1.1 Data Preparation and Loading](#1.1)
#     * [1.2 Data Partitioning in RDD](#1.2)
#     * [1.3 Query/Analysis](#1.3)
# * [2. Working with DataFrames](#2)
#     * [2.1 Data Preparation and Loading](#2.1)
#     * [2.2 Query/Analysis](#2.2)
#     * [2.3 Severity Analysis](#2.3)
#     * [Crash Severity Analysis - For Part B](#b)
#     * [2.4 RDDs vs DataFrame vs Spark SQL](#2.4)

# %% [markdown]
# # 1. Working with RDD <a class="anchor" id="1"></a>
# ## 1.1 Data Preparation and Loading <a class="anchor" id="1.1"></a>

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 1. Write the code to create a SparkContext object using SparkSession, which tells Spark
# how to access a cluster. To create a SparkSession you first need to build a SparkConf
# object that contains information about your application. Give an appropriate name for
# your application and run Spark locally with as many working processors as logical
# cores on your machine .

# %%
# Import SparkConf class into program
from pyspark import SparkConf

# Run Spark locally with as many working processors as logical cores on the machine
master = 'local[*]'
# Setup an appropriate application name
app_name = 'Analyzing Road Crash Data'
# Setup configuration parameters for Spark
spark_conf = SparkConf().setMaster(master).setAppName(app_name)

# Import SparkSession classes 
from pyspark.sql import SparkSession # Spark SQL

# Initialize Spark Session and create a SparkContext Object
spark = SparkSession.builder.config(conf = spark_conf).getOrCreate()
sc = spark.sparkContext
sc.setLogLevel('ERROR')

# %%
# Import the required necessary libraries throughout the notebook
import csv
import pandas as pd
import numpy as np

from pyspark.rdd import RDD
import pyspark.sql.functions as f
from pyspark.sql.window import Window

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 2. Import all the “Units” csv files from 2015-2019 into a single RDD.<br>

# %%
# Import all the Units csv files into a single RDD
rdd_units = sc.textFile('*Units.csv').mapPartitions(lambda x: csv.reader(x))

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 3. Import all the “Crashes” csv files from 2015-2019 into a single RDD.

# %%
# Import all the Crashes csv files into a single RDD
rdd_crash = sc.textFile('*Crash.csv').mapPartitions(lambda x: csv.reader(x))

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 4. For each Units and Crashes RDDs, remove the header rows and display the total
# count and first 10 records.

# %%
# Extract the header from the RDD
header_units = rdd_units.first()
# Filter out the header from the RDD
rdd_units = rdd_units.filter(lambda x : x != header_units)

# Print out the total count and show the first 10 rows of the RDD
print('Total Count of Units: {}'.format(rdd_units.count()), '\n')
rdd_units.take(10)
# Out:
# Total Count of Units: 153854
# [['2016-1-15/08/2019',
#   '01',
#   '0',
#   'SA',
#   'OMNIBUS',
#   '2011',
#   'North',
#   'Male',
#   '056',
#   'SA',
#   'HR',
#   'Full',
#   'Not Towing',
#   'Straight Ahead',
#   '010',
#   '5121',
#   '',
#   ''],
#  ['2016-1-15/08/2019',
#   '02',
#   '1',
#   '',
#   'Pedestrian on Road',
#   '',
#   'East',
#   'Male',
#   '072',
#   '',
#   '',
#   '',
#   '',
#   'Walking on Road',
#   '',
#   '5084',
#   '',
#   ''],
#  ['2016-2-15/08/2019',
#   '01',
#   '0',
#   'SA',
#   'Motor Cars - Sedan',
#   '2004',
#   'Unknown',
#   'Female',
#   '023',
#   'SA',
#   'C ',
#   'Full',
#   'Not Towing',
#   'Straight Ahead',
#   '001',
#   '5087',
#   '',
#   ''],
#  ['2016-2-15/08/2019',
#   '02',
#   '0',
#   'SA',
#   'Station Wagon',
#   '2008',
#   'Unknown',
#   'Male',
#   '040',
#   'SA',
#   'C ',
#   'Full',
#   'Not Towing',
#   'Straight Ahead',
#   '001',
#   '5084',
#   '',
#   ''],
#  ['2016-3-15/08/2019',
#   '01',
#   '0',
#   'SA',
#   'RIGID TRUCK LGE GE 4.5T',
#   '1990',
#   'South',
#   'Unknown',
#   'XXX',
#   'SA',
#   'MR',
#   'Provisional 2',
#   'Not Towing',
#   'Straight Ahead',
#   '001',
#   '5115',
#   '',
#   ''],
#  ['2016-3-15/08/2019',
#   '02',
#   '0',
#   'SA',
#   'Panel Van',
#   '2013',
#   'South',
#   'Male',
#   '023',
#   'SA',
#   'C ',
#   'Full',
#   'Not Towing',
#   'Straight Ahead',
#   '001',
#   '5110',
#   '',
#   ''],
#  ['2016-4-15/08/2019',
#   '01',
#   '0',
#   'SA',
#   'Station Wagon',
#   '2002',
#   'East',
#   'Female',
#   '033',
#   'SA',
#   'C ',
#   'Full',
#   'Not Towing',
#   'Straight Ahead',
#   '001',
#   '5169',
#   '',
#   ''],
#  ['2016-4-15/08/2019',
#   '02',
#   '0',
#   'UNKNOWN',
#   'Other Defined Special Vehicle',
#   'XXXX',
#   'North',
#   'Unknown',
#   'XXX',
#   'UNKNOWN',
#   'XX',
#   'Unknown',
#   'Unknown',
#   'Reversing',
#   '001',
#   'XXXX',
#   '',
#   ''],
#  ['2016-5-15/08/2019',
#   '01',
#   '1',
#   'SA',
#   'Motor Cars - Sedan',
#   '1997',
#   'South East',
#   'Male',
#   '042',
#   'SA',
#   'C ',
#   'Full',
#   'Not Towing',
#   'Right Turn',
#   '001',
#   'XXXX',
#   '',
#   ''],
#  ['2016-5-15/08/2019',
#   '02',
#   '2',
#   'SA',
#   'Utility',
#   '2015',
#   'North East',
#   'Male',
#   '059',
#   'SA',
#   'MC',
#   'Full',
#   'Not Towing',
#   'Straight Ahead',
#   '002',
#   '5114',
#   '',
#   '']]

# %%
# Extract the header from the RDD
header_crash = rdd_crash.first() #extract header
# Filter out the header from the RDD
rdd_crash = rdd_crash.filter(lambda x : x != header_crash)

# Print out the total count and show the first 10 rows of the RDD
print('Total Count of Crashes: {}'.format(rdd_crash.count()), '\n')
rdd_crash.take(10)
# Out:
# Total Count of Crashes: 72006
# [['2019-1-8/07/2020',
#   '2 Metropolitan',
#   'HAMPSTEAD GARDENS',
#   '5086',
#   'CITY OF PORT ADELAIDE ENFIELD',
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '2019',
#   'June',
#   'Wednesday',
#   '11:15 am',
#   '060',
#   'Cross Road',
#   'Straight road',
#   'Level',
#   'Not Applicable',
#   'Sealed',
#   'Dry',
#   'Not Raining',
#   'Daylight',
#   'Right Angle',
#   '01',
#   'Driver Rider',
#   '1: PDO',
#   'Give Way Sign',
#   '',
#   '',
#   '1331810.03',
#   '1676603.26',
#   '13318101676603'],
#  ['2019-2-8/07/2020',
#   '2 Metropolitan',
#   'DRY CREEK',
#   '5094',
#   'CITY OF SALISBURY',
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '2019',
#   'January',
#   'Tuesday',
#   '12:49 am',
#   '090',
#   'Divided Road',
#   'Straight road',
#   'Level',
#   'Not Applicable',
#   'Sealed',
#   'Dry',
#   'Not Raining',
#   'Night',
#   'Rear End',
#   '02',
#   'Driver Rider',
#   '1: PDO',
#   'No Control',
#   '',
#   '',
#   '1328376.2',
#   '1682942.63',
#   '13283761682943'],
#  ['2019-3-8/07/2020',
#   '2 Metropolitan',
#   'MILE END',
#   '5031',
#   'CITY OF WEST TORRENS',
#   '2',
#   '1',
#   '0',
#   '0',
#   '1',
#   '2019',
#   'January',
#   'Tuesday',
#   '12:00 am',
#   '060',
#   'Divided Road',
#   'Straight road',
#   'Level',
#   'Not Applicable',
#   'Sealed',
#   'Dry',
#   'Not Raining',
#   'Night',
#   'Hit Pedestrian',
#   '01',
#   'Driver Rider',
#   '2: MI',
#   'No Control',
#   '',
#   '',
#   '1325819.68',
#   '1670994.26',
#   '13258201670994'],
#  ['2019-4-8/07/2020',
#   '2 Metropolitan',
#   'PARALOWIE',
#   '5108',
#   'CITY OF SALISBURY',
#   '2',
#   '1',
#   '0',
#   '1',
#   '0',
#   '2019',
#   'January',
#   'Tuesday',
#   '12:05 am',
#   '050',
#   'Not Divided',
#   'CURVED, VIEW OPEN',
#   'Level',
#   'Not Applicable',
#   'Sealed',
#   'Dry',
#   'Not Raining',
#   'Night',
#   'Hit Fixed Object',
#   '01',
#   'Driver Rider',
#   '3: SI',
#   'No Control',
#   '',
#   '',
#   '1328320.6',
#   '1690237.08',
#   '13283211690237'],
#  ['2019-5-8/07/2020',
#   '2 Metropolitan',
#   'MOUNT BARKER',
#   '5251',
#   'DC MT.BARKER.                 ',
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '2019',
#   'January',
#   'Tuesday',
#   '05:15 am',
#   '110',
#   'Divided Road',
#   'Straight road',
#   'Slope',
#   'Not Applicable',
#   'Sealed',
#   'Dry',
#   'Not Raining',
#   'Night',
#   'Hit Animal',
#   '02',
#   'Animal',
#   '1: PDO',
#   'No Control',
#   '',
#   '',
#   '1353279.99',
#   '1655645.15',
#   '13532801655645'],
#  ['2019-6-8/07/2020',
#   '2 Metropolitan',
#   'TORRENSVILLE',
#   '5031',
#   'CITY OF WEST TORRENS',
#   '2',
#   '1',
#   '0',
#   '0',
#   '1',
#   '2019',
#   'January',
#   'Tuesday',
#   '07:00 am',
#   '050',
#   'Divided Road',
#   'Straight road',
#   'Level',
#   'Not Applicable',
#   'Sealed',
#   'Dry',
#   'Not Raining',
#   'Daylight',
#   'Hit Fixed Object',
#   '01',
#   'Driver Rider',
#   '2: MI',
#   'No Control',
#   '',
#   '',
#   '1324652.75',
#   '1672027.64',
#   '13246531672028'],
#  ['2019-7-8/07/2020',
#   '2 Metropolitan',
#   'BEDFORD PARK',
#   '5042',
#   'CC MITCHAM.                   ',
#   '2',
#   '3',
#   '0',
#   '0',
#   '3',
#   '2019',
#   'January',
#   'Tuesday',
#   '09:40 am',
#   '050',
#   'Cross Road',
#   'Straight road',
#   'Level',
#   'Not Applicable',
#   'Sealed',
#   'Dry',
#   'Not Raining',
#   'Daylight',
#   'Right Angle',
#   '02',
#   'Driver Rider',
#   '2: MI',
#   'Traffic Signals',
#   '',
#   '',
#   '1325156.2',
#   '1660414.38',
#   '13251561660414'],
#  ['2019-8-8/07/2020',
#   '3 Country',
#   'WYE',
#   '5291',
#   'DISTRICT COUNCIL OF GRANT',
#   '1',
#   '1',
#   '0',
#   '0',
#   '1',
#   '2019',
#   'January',
#   'Tuesday',
#   '12:15 pm',
#   '110',
#   'Not Divided',
#   'CURVED, VIEW OPEN',
#   'Level',
#   'Not Applicable',
#   'Sealed',
#   'Dry',
#   'Not Raining',
#   'Daylight',
#   'Roll Over',
#   '01',
#   'Driver Rider',
#   '2: MI',
#   'No Control',
#   '',
#   '',
#   '1517347.8',
#   '1321979.33',
#   '15173481321979'],
#  ['2019-9-8/07/2020',
#   '3 Country',
#   'MOUNT GAMBIER',
#   '5290',
#   'CC MT.GAMBIER.                ',
#   '1',
#   '1',
#   '0',
#   '0',
#   '1',
#   '2019',
#   'January',
#   'Tuesday',
#   '11:45 am',
#   '050',
#   'T-Junction',
#   'Straight road',
#   'Bottom of Hill',
#   'Not Applicable',
#   'Sealed',
#   'Dry',
#   'Not Raining',
#   'Daylight',
#   'Roll Over',
#   '01',
#   'Driver Rider',
#   '2: MI',
#   'Stop Sign',
#   '',
#   '',
#   '1510220.05',
#   '1340472.35',
#   '15102201340472'],
#  ['2019-10-8/07/2020',
#   '3 Country',
#   'OVERLAND CORNER',
#   '5330',
#   'THE BERRI BARMERA COUNCIL',
#   '1',
#   '1',
#   '0',
#   '1',
#   '0',
#   '2019',
#   'January',
#   'Tuesday',
#   '12:30 pm',
#   '080',
#   'Not Divided',
#   'CURVED, VIEW OPEN',
#   'Slope',
#   'Not Applicable',
#   'Sealed',
#   'Dry',
#   'Not Raining',
#   'Daylight',
#   'Roll Over',
#   '01',
#   'Driver Rider',
#   '3: SI',
#   'No Control',
#   '',
#   '',
#   '1492599.9',
#   '1749395.71',
#   '14926001749396']]

# %% [markdown]
# ## 1.2 Data Partitioning in RDD<a class="anchor" id="1.2"></a>

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 1. How many partitions do the above RDDs have? How is the data in these RDDs
# partitioned by default, when we do not explicitly specify any partitioning strategy?

# %%
# Print the default number of partitions for both the RDDs
print('Number of partitions for the Units RDD:', rdd_units.getNumPartitions())
print('Number of partitions for the Crash RDD:', rdd_crash.getNumPartitions())
# Out:
# Number of partitions for the Units RDD: 5
# Number of partitions for the Crash RDD: 5

# %% [markdown]
#  <div class="alert alert-block alert-warning">
#  <span style="color: green"><b>Answer</b></span><br>
# Spark assigns a new InputFileReader task to every chunk of file that it reads into RDDs, unless specified explicitly about the number of partitions and the partitioning strategy. This helps in segregating the files in separate partitions and maintaining the integrity of the file structure. Here, 5 different CSV files have been imported while creating each of the 2 RDDs. Hence, each file has been stored in a different partition, creating a total of 5 partitions for both the RDDs.

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 2. In the “Units” csv dataset, there is a column called Lic State which shows the state
# where the vehicle is registered. Assume we want to keep all the data related to SA in
# one partition and the rest of the data in another partition.

# %% [markdown]
#  <div class="alert alert-block alert-info">
# a. Create a Key Value Pair RDD with Lic State as the key and rest of the other
# columns as value.

# %%
# Create a Key Value Pair with Lic State as the key
rdd_units_kv = rdd_units.map(lambda x: (x[9], x[0:9] + x[10:]))

# %% [markdown]
#  <div class="alert alert-block alert-info">
# b. Write the code to implement this partitioning in RDD using appropriate
# partitioning functions.

# %%
# Define the number of partitions
no_of_partitions = 2;

# Define the hash function with the 'SA' lic state condition
def hash_function(key):
    if key == 'SA':
        return 2
    else:
        return 3

# Carry out the hash partitioning
hash_partitioned_rdd = rdd_units_kv.partitionBy(no_of_partitions, hash_function)

# %% [markdown]
#  <div class="alert alert-block alert-info">
# c. Write the code to print the number of records in each partition. What does it
# tell about the data skewness?

# %%
# Define a function to print the number of partitions and the number of records in each partition
def print_partitions(data):
    if isinstance(data, RDD):
        numPartitions = data.getNumPartitions()
        partitions = data.glom().collect()
    else:
        numPartitions = data.rdd.getNumPartitions()
        partitions = data.rdd.glom().collect()
    
    print(f'Number of Partitions: {numPartitions}\n')
    print(f'Number of records in each partition:')
    for index, partition in enumerate(partitions):
        print(f'Partition {index}: {len(partition)} records')

# Print the number of partitions and the number of records in each partition
print_partitions(hash_partitioned_rdd)
# Out:
# Number of Partitions: 2
#
# Number of records in each partition:
# Partition 0: 109684 records
# Partition 1: 44170 records

# %% [markdown]
#  <div class="alert alert-block alert-warning">
#  <span style="color: green"><b>Answer</b></span><br>
# The partitions above tell us that the data is highly skewed as partition 0 has more than double the records in partition 1. This will affect the processing performance of the data due to inefficient load balancing.

# %% [markdown]
# ## 1.3 Query/Analysis<a class="anchor" id="1.3"></a>

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 1. Find the average age of male and female drivers separately.

# %%
# Create a Key Value pair for sex and age, and clean the age data in RDD
rdd_units_driver = rdd_units.map(lambda x: (x[7], x[8]))\
                            .filter(lambda x: x[0] != 'Unknown')\
                            .filter(lambda x: x[1] != 'XXX')\
                            .filter(lambda x: x[0] != '')\
                            .filter(lambda x: x[1] != '')\
                            .map(lambda x: (x[0], int(x[1])))


# Filter the RDD only for the ages of male drivers
rdd_units_driver_male = rdd_units_driver.filter(lambda x : x[0] == 'Male')
# Count the male drivers in the RDD
male_count = rdd_units_driver_male.count()
# Calculate the average age of the male drivers
male_avg_age = rdd_units_driver_male.reduceByKey(lambda x, y: x + y)
# Store the average age of male drivers as a list
avg_age_male = male_avg_age.collect()

# Print out the average age of male drivers
print('The average age of male drivers is', round(avg_age_male[0][1] / male_count, 2), 'years.')


# Filter the RDD only for the ages of female drivers
rdd_units_driver_female = rdd_units_driver.filter(lambda x : x[0] == 'Female')
# Count the female drivers in the RDD
female_count = rdd_units_driver_female.count()
# Calculate the average age of the female drivers
female_avg_age = rdd_units_driver_female.reduceByKey(lambda x, y: x + y)
# Store the average age of female drivers as a list
avg_age_female = female_avg_age.collect()

# Print out the average age of female drivers
print('The average age of female drivers is', round(avg_age_female[0][1] / female_count, 2), 'years.')
# Out:
# The average age of male drivers is 40.98 years.
# The average age of female drivers is 40.39 years.

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 2. What is the oldest and the newest vehicle year involved in the accident? Display the
# Registration State, Year and Unit type of the vehicle.

# %%
# Clean the year data and create a Key Value pair for the RDD
rdd_units_vehicle = rdd_units.map(lambda x: (x[5], (x[3], x[4])))\
                            .filter(lambda x: x[0] != 'XXXX')\
                            .filter(lambda x: x[0] != '')\
                            .map(lambda x: (int(x[0]), (x[1][0], x[1][1])))\
                            .filter(lambda x: x[0] != 0)

# Extract the minimum and the maximum values of the year data 
rdd_units_vehicle_min_max = rdd_units_vehicle.map(lambda x: x[0])
year_min = rdd_units_vehicle_min_max.min()
year_max = rdd_units_vehicle_min_max.max()

# Create the final RDD with the details of the unique oldest vehicles
rdd_oldest_vehicle = rdd_units_vehicle.filter(lambda x: x[0] == year_min)\
                                    .map(lambda x: (x[1][0], x[0], x[1][1])).distinct()

# Create the final RDD with the details of the unique newest vehicles
rdd_newest_vehicle = rdd_units_vehicle.filter(lambda x: x[0] == year_max)\
                                    .map(lambda x: (x[1][0], x[0], x[1][1])).distinct()

# %%
# Show the RDD with the oldest vehicle data
rdd_oldest_vehicle.collect()
# Out:
# [('SA', 1900, 'RIGID TRUCK LGE GE 4.5T'),
#  ('SA', 1900, 'Motor Cycle'),
#  ('VIC', 1900, 'Motor Cycle')]

# %%
# Show the RDD with the newest vehicle data
rdd_newest_vehicle.collect()
# Out:
# [('SA', 2019, 'Station Wagon'),
#  ('VIC', 2019, 'Station Wagon'),
#  ('SA', 2019, 'BDOUBLE - ROAD TRAIN'),
#  ('SA', 2019, 'Motor Vehicle - Type Unknown'),
#  ('SA', 2019, 'Light Truck LT 4.5T'),
#  ('QLD', 2019, 'RIGID TRUCK LGE GE 4.5T'),
#  ('SA', 2019, 'OMNIBUS'),
#  ('SA', 2019, 'Utility'),
#  ('VIC', 2019, 'Utility'),
#  ('SA', 2019, 'SEMI TRAILER'),
#  ('SA', 2019, 'Other Defined Special Vehicle'),
#  ('VIC', 2019, 'Motor Cars - Sedan'),
#  ('NT', 2019, 'Station Wagon'),
#  ('SA', 2019, 'Scooter'),
#  ('NSW', 2019, 'Motor Cars - Sedan'),
#  ('VIC', 2019, 'BDOUBLE - ROAD TRAIN'),
#  ('SA', 2019, 'Motor Cars - Sedan'),
#  ('SA', 2019, 'Motor Cycle'),
#  ('QLD', 2019, 'SEMI TRAILER'),
#  ('SA', 2019, 'RIGID TRUCK LGE GE 4.5T'),
#  ('SA', 2019, 'Panel Van')]

# %% [markdown]
# # 2 Working with DataFrames<a class="anchor" id="2"></a>
# ## 2.1 Data Preparation and Loading<a class="anchor" id="2.1"></a>

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 1. Load all units and crash data into two separate dataframes.

# %%
# Import all the Units and Crashes csv files into single respective DataFrames
df_units = spark.read.csv('*Units.csv', inferSchema = True, header = True)
df_crash = spark.read.csv('*Crash.csv', inferSchema = True, header = True)

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 2. Display the schema of the final two dataframes.

# %%
# Show the schema for the Units DF
df_units.printSchema()
# Out:
# root
#  |-- REPORT_ID: string (nullable = true)
#  |-- Unit No: integer (nullable = true)
#  |-- No Of Cas: integer (nullable = true)
#  |-- Veh Reg State: string (nullable = true)
#  |-- Unit Type: string (nullable = true)
#  |-- Veh Year: string (nullable = true)
#  |-- Direction Of Travel: string (nullable = true)
#  |-- Sex: string (nullable = true)
#  |-- Age: string (nullable = true)
#  |-- Lic State: string (nullable = true)
#  |-- Licence Class: string (nullable = true)
#  |-- Licence Type: string (nullable = true)
#  |-- Towing: string (nullable = true)
#  |-- Unit Movement: string (nullable = true)
#  |-- Number Occupants: string (nullable = true)
#  |-- Postcode: string (nullable = true)
#  |-- Rollover: string (nullable = true)
#  |-- Fire: string (nullable = true)

# %%
# Show the schema for the Crashes DF
df_crash.printSchema()
# Out:
# root
#  |-- REPORT_ID: string (nullable = true)
#  |-- Stats Area: string (nullable = true)
#  |-- Suburb: string (nullable = true)
#  |-- Postcode: integer (nullable = true)
#  |-- LGA Name: string (nullable = true)
#  |-- Total Units: integer (nullable = true)
#  |-- Total Cas: integer (nullable = true)
#  |-- Total Fats: integer (nullable = true)
#  |-- Total SI: integer (nullable = true)
#  |-- Total MI: integer (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Month: string (nullable = true)
#  |-- Day: string (nullable = true)
#  |-- Time: string (nullable = true)
#  |-- Area Speed: integer (nullable = true)
#  |-- Position Type: string (nullable = true)
#  |-- Horizontal Align: string (nullable = true)
#  |-- Vertical Align: string (nullable = true)
#  |-- Other Feat: string (nullable = true)
#  |-- Road Surface: string (nullable = true)
#  |-- Moisture Cond: string (nullable = true)
#  |-- Weather Cond: string (nullable = true)
#  |-- DayNight: string (nullable = true)
#  |-- Crash Type: string (nullable = true)
#  |-- Unit Resp: integer (nullable = true)
#  |-- Entity Code: string (nullable = true)
#  |-- CSEF Severity: string (nullable = true)
#  |-- Traffic Ctrls: string (nullable = true)
#  |-- DUI Involved: string (nullable = true)
#  |-- Drugs Involved: string (nullable = true)
#  |-- ACCLOC_X: double (nullable = true)
#  |-- ACCLOC_Y: double (nullable = true)
#  |-- UNIQUE_LOC: long (nullable = true)

# %% [markdown]
# ## 2.2 Query/Analysis<a class="anchor" id="2.2"></a>

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 1. Find all the crash events in Adelaide where the total number of casualties in the event
# is more than 3.

# %%
# Filter the data to Adelaide suburb and the total casualties being more than 3
crash_df = df_crash.filter((f.col('Suburb') == 'ADELAIDE') & (f.col('Total Cas') > 3))
# Convert the DF to a Pandas DF for better readability and display the results
crash_df.toPandas()
# Out:
#                REPORT_ID Stats Area    Suburb  Postcode          LGA Name  \
# 0    2018-601-17/01/2020     1 City  ADELAIDE      5000  CITY OF ADELAIDE
# 1   2017-1613-15/08/2019     1 City  ADELAIDE      5000  CITY OF ADELAIDE
# 2  2017-12182-15/08/2019     1 City  ADELAIDE      5000  CITY OF ADELAIDE
# 3   2019-10404-8/07/2020     1 City  ADELAIDE      5000  CITY OF ADELAIDE
#
#    Total Units  Total Cas  Total Fats  Total SI  Total MI  ...  \
# 0            8          4           0         2         2  ...
# 1            2          4           0         0         4  ...
# 2            6          5           0         1         4  ...
# 3            4          6           0         0         6  ...
#
#        Crash Type Unit Resp   Entity Code CSEF Severity    Traffic Ctrls  \
# 0  Hit Pedestrian         1  Driver Rider         3: SI       No Control
# 1      Right Turn         1  Driver Rider         2: MI  Traffic Signals
# 2  Hit Pedestrian         1  Driver Rider         3: SI  Traffic Signals
# 3      Right Turn         1  Driver Rider         2: MI       No Control
#
#   DUI Involved Drugs Involved    ACCLOC_X    ACCLOC_Y      UNIQUE_LOC
# 0         None           None  1329806.36  1670224.76  13298061670225
# 1         None           None  1327951.24  1669556.92  13279511669557
# 2         None           None  1329016.20  1670995.07  13290161670995
# 3         None           None  1327088.72  1670880.07  13270891670880
#
# [4 rows x 33 columns]

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 2. Display 10 crash events with highest casualties.

# %%
# Sort the DF by total casualties in descending order
crash_df = df_crash.sort('Total Cas', ascending = False)
# Convert the DF to a Pandas DF for better readability and display 10 crash events as results
crash_df.toPandas().head(10)
# Out:
#                REPORT_ID      Stats Area         Suburb  Postcode  \
# 0    2017-288-15/08/2019  2 Metropolitan     PARA HILLS      5096
# 1   2016-3035-15/08/2019  2 Metropolitan        HACKHAM      5163
# 2   2016-6630-15/08/2019  2 Metropolitan  KANGAROO FLAT      5118
# 3   2019-11734-8/07/2020  2 Metropolitan          STURT      5047
# 4   2016-7073-15/08/2019       3 Country       MERRITON      5523
# 5  2016-14407-15/08/2019       3 Country      STOCKWELL      5355
# 6   2015-2823-21/08/2019       3 Country         HAWKER      5434
# 7   2016-8547-15/08/2019       3 Country        WINDSOR      5501
# 8   2015-6965-21/08/2019       3 Country       BEAUFORT      5550
# 9  2015-12591-21/08/2019       3 Country        MALLALA      5502
#
#                          LGA Name  Total Units  Total Cas  Total Fats  \
# 0               CITY OF SALISBURY            2         11           0
# 1             CITY OF ONKAPARINGA            3          9           3
# 2          LIGHT REGIONAL COUNCIL            3          9           0
# 3  CC MARION.                                2          9           0
# 4  PT.PIRIE CITY & DIST. COUNCIL             2          8           4
# 5            THE BAROSSA COUNCIL.            2          8           1
# 6    THE FLINDERS RANGES COUNCIL.            1          8           0
# 7  DC MALLALA.                               4          7           0
# 8         YORKE PENINSULA COUNCIL            3          7           3
# 9  DC MALLALA.                               2          7           0
#
#    Total SI  Total MI  ...   Crash Type Unit Resp   Entity Code CSEF Severity  \
# 0         1        10  ...  Right Angle         1  Driver Rider         3: SI
# 1         5         1  ...   Right Turn         1  Driver Rider      4: Fatal
# 2         2         7  ...      Head On         1  Driver Rider         3: SI
# 3         1         8  ...   Right Turn         2  Driver Rider         3: SI
# 4         3         1  ...      Head On         1  Driver Rider      4: Fatal
# 5         6         1  ...      Head On         1  Driver Rider      4: Fatal
# 6         0         8  ...    Roll Over         1  Driver Rider         2: MI
# 7         1         6  ...     Rear End         2  Driver Rider         3: SI
# 8         4         0  ...      Head On         9         Other      4: Fatal
# 9         2         5  ...  Right Angle         1  Driver Rider         3: SI
#
#      Traffic Ctrls DUI Involved Drugs Involved    ACCLOC_X    ACCLOC_Y  \
# 0        Stop Sign         None           None  1334428.90  1683032.96
# 1       No Control         None           None  1320361.49  1645195.63
# 2       No Control         None           None  1339316.32  1710314.92
# 3  Traffic Signals         None           None  1324428.84  1659884.95
# 4       No Control         None           None  1293759.89  1840109.96
# 5       No Control         None           None  1373964.45  1723462.57
# 6       No Control         None           None  1315077.61  2022309.34
# 7       No Control         None              Y  1306853.11  1724952.66
# 8       No Control         None           None  1287930.19  1761652.36
# 9    Give Way Sign         None           None  1325122.01  1724860.95
#
#      UNIQUE_LOC
# 0  1.334429e+13
# 1  1.320361e+13
# 2  1.339316e+13
# 3  1.324429e+13
# 4  1.293760e+13
# 5  1.373964e+13
# 6  1.315078e+13
# 7  1.306853e+13
# 8  1.287930e+13
# 9  1.325122e+13
#
# [10 rows x 33 columns]

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 3. Find the total number of fatalities for each crash type.

# %%
# Group by crash type, aggregate the sum of fatalities accordingly, then sort them based on the total sum and show results
df_crash.groupBy('Crash Type').agg({'Total Fats': 'sum'})\
        .sort('sum(Total Fats)', ascending = False)\
        .withColumnRenamed('sum(Total Fats)', 'Total Fatalities').show()
# Out:
# +--------------------+----------------+
# |          Crash Type|Total Fatalities|
# +--------------------+----------------+
# |    Hit Fixed Object|             152|
# |             Head On|              86|
# |      Hit Pedestrian|              70|
# |           Roll Over|              57|
# |         Right Angle|              45|
# |          Side Swipe|              20|
# |          Right Turn|              18|
# |            Rear End|              16|
# |  Hit Parked Vehicle|               9|
# |          Hit Animal|               4|
# |  Hit Object on Road|               2|
# |               Other|               2|
# |Left Road - Out o...|               1|
# +--------------------+----------------+

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 4. Find the total number of casualties for each suburb when the vehicle was driven by an
# unlicensed driver. You are required to display the name of the suburb and the total
# number of casualties.

# %%
# Filter the units DF to only the unlicenced drivers
df_units_unlicenced = df_units.filter(f.col('Licence Type') == 'Unlicenced')

# Join both the DFs on REPORT_ID
df_joined = df_units_unlicenced.join(df_crash,
                                     df_units_unlicenced.REPORT_ID == df_crash.REPORT_ID,
                                     how = 'inner')

# Group by suburb, aggregate the sum of casualties accordingly and sort them based on the total sum
df_joined.groupBy('Suburb').agg({'Total Cas': 'sum'}).sort('sum(Total Cas)', ascending = False)\
            .withColumnRenamed('sum(Total Cas)', 'Total Casualties').show() # Rename the column as required and show
# Out:
# +---------------+----------------+
# |         Suburb|Total Casualties|
# +---------------+----------------+
# |       ADELAIDE|              19|
# |      SALISBURY|              18|
# |      DRY CREEK|              18|
# | SALISBURY EAST|              16|
# |       PROSPECT|              14|
# | NORTH ADELAIDE|              13|
# |        ENFIELD|              12|
# |   ANDREWS FARM|              12|
# |SALISBURY SOUTH|              11|
# |SALISBURY DOWNS|              11|
# |     INGLE FARM|              11|
# |   BEDFORD PARK|              11|
# | ELIZABETH PARK|              10|
# |     MUNNO PARA|              10|
# |  MORPHETT VALE|              10|
# |         BURTON|              10|
# |   MOUNT BARKER|              10|
# |   MAWSON LAKES|              10|
# |SALISBURY PLAIN|              10|
# |ELIZABETH GROVE|               9|
# +---------------+----------------+
# only showing top 20 rows

# %% [markdown]
# ## 2.3 Severity Analysis<a class="anchor" id="2.3"></a>

# %%
# Select only the required columns from the crash DF for the entire severity analysis to reduce the query load
df_crash_sa = df_crash.select(f.col('CSEF Severity'), f.col('Drugs Involved'), f.col('DUI Involved'))

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 1. Find the total number of crash events for each severity level. Which severity level is the
# most common?

# %%
# Group by the severity level and aggregate the count of the number of records
df_crash_sa.groupBy('CSEF Severity').count().withColumnRenamed('count', 'Count').show()
# Out:
# +-------------+-----+
# |CSEF Severity|Count|
# +-------------+-----+
# |     4: Fatal|  451|
# |        2: MI|21881|
# |       1: PDO|46696|
# |        3: SI| 2978|
# +-------------+-----+

# %% [markdown]
#  <div class="alert alert-block alert-warning">
#  <span style="color: green"><b>Answer</b></span><br>
# The PDO, i.e. Property Damage Only is the most common severity level among the 4, with a total count of 46696 crash incidents.

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 2. Compute the total number of crash events for each severity level and the percentage
# for the four different scenarios.

# %% [markdown]
#  <div class="alert alert-block alert-info">
# a. When the driver is tested positive on drugs.

# %%
# Filter the DF based on the requirement, group by severity level, aggregate the count accordingly
# and then compute the percentage of the count
a = df_crash_sa.filter((f.col('Drugs Involved') == 'Y') & f.col('DUI Involved').isNull()).groupBy('CSEF Severity').count()\
            .withColumn('Percentage', f.round(f.col('count') / f.sum('count').over(Window.partitionBy()) * 100, 2))\
            .withColumnRenamed('count', 'Count')

# Display the results
a.show()
# Out:
# +-------------+-----+----------+
# |CSEF Severity|Count|Percentage|
# +-------------+-----+----------+
# |     4: Fatal|   55|       5.1|
# |        2: MI|  660|     61.17|
# |       1: PDO|  152|     14.09|
# |        3: SI|  212|     19.65|
# +-------------+-----+----------+

# %% [markdown]
#  <div class="alert alert-block alert-info">
# b. When the driver is tested positive for blood alcohol concentration.

# %%
# Filter the DF based on the requirement, group by severity level, aggregate the count accordingly
# and then compute the percentage of the count
b = df_crash_sa.filter((f.col('DUI Involved') == 'Y') & f.col('Drugs Involved').isNull()).groupBy('CSEF Severity').count()\
            .withColumn('Percentage', f.round(f.col('count') / f.sum('count').over(Window.partitionBy()) * 100, 2))\
            .withColumnRenamed('count', 'Count')

# Display the results
b.show()
# Out:
# +-------------+-----+----------+
# |CSEF Severity|Count|Percentage|
# +-------------+-----+----------+
# |     4: Fatal|   52|      2.51|
# |        2: MI|  648|     31.26|
# |       1: PDO| 1149|     55.43|
# |        3: SI|  224|     10.81|
# +-------------+-----+----------+

# %% [markdown]
#  <div class="alert alert-block alert-info">
# c. When the driver is tested positive for both drugs and blood alcohol

# %%
# Filter the DF based on the requirement, group by severity level, aggregate the count accordingly
# and then compute the percentage of the count
c = df_crash_sa.filter((f.col('Drugs Involved') == 'Y') & (f.col('DUI Involved') == 'Y'))\
            .groupBy('CSEF Severity').count()\
            .withColumn('Percentage', f.round(f.col('count') / f.sum('count').over(Window.partitionBy()) * 100, 2))\
            .withColumnRenamed('count', 'Count')

# Display the results
c.show()
# Out:
# +-------------+-----+----------+
# |CSEF Severity|Count|Percentage|
# +-------------+-----+----------+
# |     4: Fatal|   27|     15.43|
# |        2: MI|   89|     50.86|
# |       1: PDO|   24|     13.71|
# |        3: SI|   35|      20.0|
# +-------------+-----+----------+

# %% [markdown]
#  <div class="alert alert-block alert-info">
# d. When the driver is tested negative for both (no alcohol and no drugs).

# %%
# Filter the DF based on the requirement, group by severity level, aggregate the count accordingly
# and then compute the percentage of the count
d = df_crash_sa.filter((f.col('Drugs Involved').isNull()) & (f.col('DUI Involved').isNull()))\
            .groupBy('CSEF Severity').count()\
            .withColumn('Percentage', f.round(f.col('count') / f.sum('count').over(Window.partitionBy()) * 100, 2))\
            .withColumnRenamed('count', 'Count')

# Display the results
d.show()
# Out:
# +-------------+-----+----------+
# |CSEF Severity|Count|Percentage|
# +-------------+-----+----------+
# |     4: Fatal|  317|      0.46|
# |        2: MI|20484|     29.83|
# |       1: PDO|45371|     66.06|
# |        3: SI| 2507|      3.65|
# +-------------+-----+----------+

# %% [markdown]
# ## Crash Severity Analysis - For Part B<a class="anchor" id="b"></a>

# %%
# Join all the results from the above 4 scenarios and generate a single result table to compare the numbers
severity_joined = a.select(f.col('CSEF Severity'), f.col('Percentage').alias('On Drugs'))\
            .join(b.select(f.col('CSEF Severity'), f.col('Percentage').alias('On Alc')), ['CSEF Severity'])\
            .join(c.select(f.col('CSEF Severity'), f.col('Percentage').alias('On Both')), ['CSEF Severity'])\
            .join(d.select(f.col('CSEF Severity'), f.col('Percentage').alias('On None')), ['CSEF Severity'])
severity_joined = severity_joined.withColumnRenamed('CSEF Severity', 'Severity Level').sort('Severity Level')

# Show the joined table for comparison
severity_joined.show()
# Out:
# +--------------+--------+------+-------+-------+
# |Severity Level|On Drugs|On Alc|On Both|On None|
# +--------------+--------+------+-------+-------+
# |        1: PDO|   14.09| 55.43|  13.71|  66.06|
# |         2: MI|   61.17| 31.26|  50.86|  29.83|
# |         3: SI|   19.65| 10.81|   20.0|   3.65|
# |      4: Fatal|     5.1|  2.51|  15.43|   0.46|
# +--------------+--------+------+-------+-------+

# %% [markdown]
#  <div class="alert alert-block alert-warning">
#  <span style="color: green"><b>Answer</b></span><br>
# After comparing the results from the 4 different scenarios, we can see that drivers tend to cause the highest proportion of fatal accidents when they are tested positive for both, i.e. drugs and alcohol. Also, there are high proportions of minor and serious injuries in this case. In the case of testing positive for drugs only, there are plenty of minor injuries to the drivers followed by some serious injuries as well, and very little fatal and property damages. We can see some distribution in the case of testing positive for alcohol only too, where the highest share is for property damages only, followed by some minor injuries and very few fatal accidents. But, the maximum property damage is caused in the case of accidents when the drivers are tested negative for both, drugs and alcohol. All the other severity levels are comparatively low in this particular case.

# %% [markdown]
# ## 2.4 RDDs vs DataFrames vs Spark SQL<a class="anchor" id="2.4"></a>

# %%
# Create SQL Views from both the Dataframes
df_units.createOrReplaceTempView('sql_units')
df_crash.createOrReplaceTempView('sql_crash')

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 1. Find the Date and Time of Crash, Number of Casualties in each unit and the Gender,
# Age, License Type of the unit driver for the suburb "Adelaide".

# %% [markdown]
# ### RDD

# %%
# %%time
# Log the time taken for the query

# Create a Key Value pair with REPORT_ID as the key and the required columns as values for both the RDDs
rdd_units_kv = rdd_units.map(lambda x: (x[0], (int(x[1]), int(x[2]), x[7], int(x[8]) if x[8].isdigit() else x[8], x[11])))
rdd_crash_kv = rdd_crash.map(lambda x: (x[0], (x[10], x[2], x[11], x[12], x[13])))

# Filter the crash RDD only for the Adelaide suburb 
rdd_crash_kv = rdd_crash_kv.filter(lambda x: x[1][1] == 'ADELAIDE')
# Join the 2 RDDs on REPORT_ID
rdd_joined = rdd_units_kv.join(rdd_crash_kv)

# Concatenate the date as required and select all the other required elements
rdd_joined = rdd_joined.map(lambda x: ((x[1][1][0] + '-' + x[1][1][2] + '-' + x[1][1][3]),
                                       x[1][1][4], x[1][0][0], x[1][0][1], x[1][0][2], x[1][0][3], x[1][0][4]))
# Sort the RDD by date and time for easy comparison with the other 2 methods
rdd_joined = rdd_joined.sortBy(lambda x: (x[0], x[1]), ascending = False)

# Print the total number of rows in the result
print('Total rows: ', rdd_joined.count())
# Show the result RDD
rdd_joined.collect()
# Out:
# Total rows:  6310
# CPU times: user 53.7 ms, sys: 16.4 ms, total: 70.1 ms
# Wall time: 4.8 s
# [('2019-September-Wednesday', '11:40 am', 1, 0, 'Male', 56, 'Full'),
#  ('2019-September-Wednesday', '11:40 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-September-Wednesday', '11:38 am', 1, 0, 'Male', 29, 'Full'),
#  ('2019-September-Wednesday', '11:38 am', 2, 1, 'Male', 73, ''),
#  ('2019-September-Wednesday', '07:55 pm', 1, 1, 'Female', 31, ''),
#  ('2019-September-Wednesday', '07:55 pm', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-September-Wednesday', '06:50 pm', 1, 0, 'Female', 75, 'Full'),
#  ('2019-September-Wednesday', '06:50 pm', 2, 0, 'Male', 39, 'Full'),
#  ('2019-September-Wednesday', '06:00 pm', 1, 1, 'Female', 38, ''),
#  ('2019-September-Wednesday', '06:00 pm', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-September-Wednesday', '04:36 pm', 1, 1, 'Male', 28, ''),
#  ('2019-September-Wednesday', '04:36 pm', 2, 1, 'Female', 33, ''),
#  ('2019-September-Wednesday', '04:10 pm', 1, 0, 'Female', 29, 'Full'),
#  ('2019-September-Wednesday', '04:10 pm', 2, 0, 'Male', 50, 'Full'),
#  ('2019-September-Wednesday', '03:30 pm', 1, 0, 'Male', 74, 'Full'),
#  ('2019-September-Wednesday', '03:30 pm', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-September-Wednesday', '03:05 pm', 1, 0, 'Male', 45, 'Full'),
#  ('2019-September-Wednesday', '03:05 pm', 2, 0, 'Male', 'XXX', ''),
#  ('2019-September-Wednesday', '02:20 pm', 1, 0, 'Female', 23, 'Unknown'),
#  ('2019-September-Wednesday', '02:20 pm', 2, 1, 'Male', 40, ''),
#  ('2019-September-Wednesday', '01:05 pm', 1, 0, 'Female', 24, 'Full'),
#  ('2019-September-Wednesday', '01:05 pm', 2, 1, 'Unknown', 'XXX', ''),
#  ('2019-September-Tuesday', '12:22 pm', 1, 0, 'Male', 48, 'Full'),
#  ('2019-September-Tuesday', '12:22 pm', 2, 0, 'Male', 41, 'Full'),
#  ('2019-September-Tuesday', '10:42 pm', 1, 0, 'Male', 30, 'Unknown'),
#  ('2019-September-Tuesday', '10:42 pm', 2, 1, 'Male', 27, ''),
#  ('2019-September-Tuesday', '06:00 pm', 1, 1, 'Male', 66, ''),
#  ('2019-September-Tuesday', '06:00 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-September-Tuesday', '05:42 pm', 1, 0, 'Female', 46, 'Full'),
#  ('2019-September-Tuesday', '05:42 pm', 2, 0, 'Male', 59, 'Full'),
#  ('2019-September-Tuesday', '05:30 pm', 1, 0, 'Female', 34, 'Full'),
#  ('2019-September-Tuesday', '05:30 pm', 2, 0, 'Male', 36, 'Full'),
#  ('2019-September-Tuesday', '04:25 pm', 1, 0, 'Female', 26, 'Provisional 1 '),
#  ('2019-September-Tuesday', '04:25 pm', 2, 0, 'Female', 22, 'Full'),
#  ('2019-September-Thursday', '12:45 pm', 1, 0, 'Male', 73, 'Full'),
#  ('2019-September-Thursday', '12:45 pm', 2, 0, 'Male', 66, 'Full'),
#  ('2019-September-Thursday', '12:30 pm', 1, 0, 'Male', 32, 'Full'),
#  ('2019-September-Thursday', '12:30 pm', 2, 0, 'Male', 33, 'Full'),
#  ('2019-September-Thursday', '10:50 pm', 1, 0, 'Male', 24, 'Unlicenced'),
#  ('2019-September-Thursday', '10:50 pm', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-September-Thursday', '09:45 am', 1, 0, 'Female', 37, ''),
#  ('2019-September-Thursday', '09:45 am', 2, 0, 'Male', 79, 'Full'),
#  ('2019-September-Thursday', '09:30 pm', 1, 1, 'Male', 45, ''),
#  ('2019-September-Thursday', '07:15 pm', 1, 2, 'Male', 28, 'Full'),
#  ('2019-September-Thursday', '07:15 pm', 2, 0, 'Male', 30, 'Full'),
#  ('2019-September-Thursday', '05:15 pm', 1, 0, 'Female', 27, 'Provisional 1 '),
#  ('2019-September-Thursday', '05:15 pm', 2, 0, 'Male', 26, 'Full'),
#  ('2019-September-Thursday', '05:10 pm', 1, 0, 'Female', 50, 'Full'),
#  ('2019-September-Thursday', '05:10 pm', 2, 0, 'Female', 26, 'Probationary'),
#  ('2019-September-Thursday', '05:05 pm', 1, 0, 'Male', 62, 'Full'),
#  ('2019-September-Thursday', '05:05 pm', 2, 0, 'Male', 29, 'Full'),
#  ('2019-September-Thursday', '05:00 pm', 1, 0, 'Female', 18, 'Provisional 2'),
#  ('2019-September-Thursday', '05:00 pm', 2, 0, 'Male', 51, 'Full'),
#  ('2019-September-Thursday', '01:12 pm', 1, 0, 'Female', 38, ''),
#  ('2019-September-Thursday', '01:12 pm', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-September-Sunday', '06:00 pm', 1, 0, 'Male', 38, 'Full'),
#  ('2019-September-Sunday', '06:00 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-September-Sunday', '04:30 pm', 1, 0, 'Female', 55, 'Full'),
#  ('2019-September-Sunday', '04:30 pm', 2, 0, 'Male', 67, 'Full'),
#  ('2019-September-Sunday', '01:15 am', 1, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-September-Sunday', '01:15 am', 2, 0, 'Male', 32, 'Full'),
#  ('2019-September-Saturday', '11:40 pm', 1, 0, 'Female', 59, 'Full'),
#  ('2019-September-Saturday', '11:40 pm', 2, 0, 'Male', 28, 'Full'),
#  ('2019-September-Saturday', '10:35 pm', 1, 0, 'Male', 20, 'Provisional 2'),
#  ('2019-September-Saturday', '10:35 pm', 2, 0, 'Male', 24, 'Full'),
#  ('2019-September-Saturday', '10:15 pm', 1, 0, 'Male', 26, ''),
#  ('2019-September-Saturday', '10:15 pm', 2, 0, 'Male', 26, 'Full'),
#  ('2019-September-Saturday', '09:40 pm', 1, 0, 'Male', 61, 'Full'),
#  ('2019-September-Saturday', '09:40 pm', 2, 0, 'Male', 21, 'Full'),
#  ('2019-September-Saturday', '09:10 am', 1, 0, 'Male', 31, 'Full'),
#  ('2019-September-Saturday', '09:10 am', 2, 0, 'Male', 61, 'Full'),
#  ('2019-September-Saturday', '05:30 pm', 1, 0, 'Male', 44, 'Full'),
#  ('2019-September-Saturday', '05:30 pm', 2, 0, 'Male', 20, 'Full'),
#  ('2019-September-Monday', '09:30 am', 1, 0, '', '', ''),
#  ('2019-September-Monday', '09:30 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-September-Monday', '09:00 am', 1, 0, 'Male', 47, 'Full'),
#  ('2019-September-Monday', '09:00 am', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-September-Monday', '07:30 am', 1, 0, 'Female', 55, 'Full'),
#  ('2019-September-Monday', '07:30 am', 2, 0, 'Male', 26, 'Full'),
#  ('2019-September-Monday', '05:50 pm', 1, 0, 'Female', 46, 'Full'),
#  ('2019-September-Monday', '05:50 pm', 2, 0, 'Female', 33, 'Full'),
#  ('2019-September-Monday', '05:50 pm', 3, 0, 'Male', 54, 'Full'),
#  ('2019-September-Monday', '05:50 pm', 4, 0, 'Male', 62, 'Full'),
#  ('2019-September-Friday', '12:40 pm', 1, 1, 'Male', 33, 'Probationary'),
#  ('2019-September-Friday', '12:40 pm', 2, 0, 'Female', 27, 'Full'),
#  ('2019-September-Friday', '07:45 pm', 1, 0, 'Female', 45, 'Full'),
#  ('2019-September-Friday', '07:45 pm', 2, 0, 'Male', 45, 'Full'),
#  ('2019-September-Friday', '05:17 pm', 1, 0, 'Male', 22, 'Full'),
#  ('2019-September-Friday', '05:17 pm', 2, 0, 'Male', 25, 'Full'),
#  ('2019-September-Friday', '04:00 pm', 1, 0, 'Male', 21, 'Full'),
#  ('2019-September-Friday', '04:00 pm', 2, 0, 'Male', 39, 'Full'),
#  ('2019-September-Friday', '03:15 pm', 1, 0, 'Male', 70, 'Full'),
#  ('2019-September-Friday', '03:15 pm', 2, 0, 'Male', 71, 'Full'),
#  ('2019-October-Wednesday', '11:30 am', 1, 0, 'Male', 74, 'Full'),
#  ('2019-October-Wednesday', '11:30 am', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-October-Wednesday', '10:30 pm', 1, 0, 'Male', 25, 'Full'),
#  ('2019-October-Wednesday', '10:30 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-October-Wednesday', '08:30 am', 1, 1, 'Male', 28, 'Full'),
#  ('2019-October-Wednesday', '08:30 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-October-Wednesday', '08:10 am', 1, 0, 'Male', 70, 'Full'),
#  ('2019-October-Wednesday', '08:10 am', 2, 1, 'Female', 27, 'Full'),
#  ('2019-October-Wednesday', '07:45 pm', 1, 0, 'Male', 45, 'Full'),
#  ('2019-October-Wednesday', '07:45 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-October-Wednesday', '05:55 pm', 1, 0, 'Female', 21, 'Full'),
#  ('2019-October-Wednesday', '05:55 pm', 2, 0, 'Male', 59, 'Full'),
#  ('2019-October-Wednesday', '05:50 pm', 1, 1, 'Female', 21, ''),
#  ('2019-October-Wednesday', '05:50 pm', 2, 0, '', '', ''),
#  ('2019-October-Wednesday', '05:20 pm', 1, 0, 'Female', 20, 'Unlicenced'),
#  ('2019-October-Wednesday', '05:20 pm', 2, 0, 'Male', 28, 'Full'),
#  ('2019-October-Wednesday', '05:05 pm', 1, 0, 'Male', 26, 'Full'),
#  ('2019-October-Wednesday', '05:05 pm', 2, 0, 'Female', 58, 'Full'),
#  ('2019-October-Wednesday', '02:00 pm', 1, 0, 'Male', 59, 'Full'),
#  ('2019-October-Wednesday', '02:00 pm', 2, 0, 'Male', 63, 'Full'),
#  ('2019-October-Tuesday', '11:30 am', 1, 0, 'Female', 25, 'Full'),
#  ('2019-October-Tuesday', '11:30 am', 2, 1, 'Female', 39, 'Full'),
#  ('2019-October-Tuesday', '10:00 am', 1, 0, '', '', ''),
#  ('2019-October-Tuesday', '10:00 am', 2, 0, 'Female', 51, 'Full'),
#  ('2019-October-Tuesday', '08:50 am', 1, 0, 'Female', 46, 'Full'),
#  ('2019-October-Tuesday', '08:50 am', 2, 0, 'Female', 27, 'Full'),
#  ('2019-October-Tuesday', '08:45 am', 1, 1, 'Female', 46, ''),
#  ('2019-October-Tuesday', '08:45 am', 2, 0, 'Male', 76, 'Full'),
#  ('2019-October-Tuesday', '05:20 pm', 1, 0, 'Female', 26, 'Full'),
#  ('2019-October-Tuesday', '05:20 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-October-Tuesday', '03:55 am', 1, 0, 'Unknown', 'XXX', 'Full'),
#  ('2019-October-Tuesday', '03:55 am', 2, 0, 'Male', 50, 'Full'),
#  ('2019-October-Tuesday', '03:15 pm', 1, 0, 'Female', 36, 'Full'),
#  ('2019-October-Tuesday', '03:15 pm', 2, 0, 'Male', 19, 'Provisional 2'),
#  ('2019-October-Thursday', '12:40 pm', 1, 0, 'Female', 17, 'Provisional 1 '),
#  ('2019-October-Thursday', '12:40 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-October-Thursday', '11:10 pm', 1, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-October-Thursday', '11:10 pm', 2, 1, 'Male', 32, ''),
#  ('2019-October-Thursday', '09:35 am', 1, 0, 'Female', 48, 'Full'),
#  ('2019-October-Thursday', '09:35 am', 2, 0, 'Male', 19, 'Learners'),
#  ('2019-October-Thursday', '09:25 am', 1, 0, 'Male', 20, 'Provisional 2'),
#  ('2019-October-Thursday', '09:25 am', 2, 0, '', '', ''),
#  ('2019-October-Thursday', '07:30 am', 1, 1, 'Male', 58, ''),
#  ('2019-October-Thursday', '07:30 am', 2, 0, 'Male', 70, 'Full'),
#  ('2019-October-Thursday', '06:17 pm', 1, 0, 'Male', 18, 'Provisional 2'),
#  ('2019-October-Thursday', '06:17 pm', 2, 1, 'Female', 60, 'Full'),
#  ('2019-October-Thursday', '05:30 pm', 1, 1, 'Male', 33, 'Full'),
#  ('2019-October-Thursday', '05:30 pm', 2, 1, 'Male', 36, 'Full'),
#  ('2019-October-Thursday', '02:00 pm', 1, 0, 'Female', 64, 'Full'),
#  ('2019-October-Thursday', '02:00 pm', 2, 0, '', '', ''),
#  ('2019-October-Sunday', '12:44 am', 1, 0, 'Male', 65, 'Full'),
#  ('2019-October-Sunday', '12:44 am', 2, 0, 'Male', 45, 'Full'),
#  ('2019-October-Sunday', '11:45 am', 1, 0, 'Female', 40, 'Full'),
#  ('2019-October-Sunday', '11:45 am', 2, 0, 'Female', 58, 'Full'),
#  ('2019-October-Sunday', '03:05 pm', 1, 0, 'Male', 64, 'Full'),
#  ('2019-October-Sunday', '03:05 pm', 2, 0, 'Female', 58, 'Full'),
#  ('2019-October-Saturday', '11:23 am', 1, 0, 'Male', 49, 'Full'),
#  ('2019-October-Saturday', '11:23 am', 2, 0, 'Male', 43, 'Full'),
#  ('2019-October-Saturday', '11:08 pm', 1, 0, 'Female', 23, 'Full'),
#  ('2019-October-Saturday', '11:08 pm', 2, 0, 'Male', 33, 'Full'),
#  ('2019-October-Saturday', '09:50 pm', 1, 0, 'Male', 29, 'Disqualified'),
#  ('2019-October-Saturday', '09:50 pm', 2, 0, 'Male', 22, 'Unknown'),
#  ('2019-October-Saturday', '09:50 pm', 3, 0, 'Female', 38, 'Unknown'),
#  ('2019-October-Saturday', '05:34 pm', 1, 0, 'Female', 48, 'Full'),
#  ('2019-October-Saturday', '05:34 pm', 2, 0, 'Female', 21, 'Provisional 2'),
#  ('2019-October-Saturday', '01:35 am', 1, 0, 'Male', 30, 'Full'),
#  ('2019-October-Saturday', '01:35 am', 2, 1, 'Female', 22, ''),
#  ('2019-October-Saturday', '01:00 pm', 1, 1, 'Female', 57, 'Full'),
#  ('2019-October-Saturday', '01:00 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-October-Monday', '08:20 am', 1, 1, 'Male', 48, 'Full'),
#  ('2019-October-Monday', '08:20 am', 2, 5, 'Male', 50, 'Full'),
#  ('2019-October-Monday', '08:20 am', 3, 0, 'Female', 37, 'Full'),
#  ('2019-October-Monday', '08:20 am', 4, 0, 'Male', 37, 'Full'),
#  ('2019-October-Monday', '06:15 pm', 1, 0, 'Male', 32, 'Full'),
#  ('2019-October-Monday', '06:15 pm', 2, 0, 'Male', 62, 'Full'),
#  ('2019-October-Monday', '05:00 pm', 1, 0, 'Male', 53, 'Full'),
#  ('2019-October-Monday', '05:00 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-October-Monday', '04:20 pm', 1, 0, 'Male', 47, 'Full'),
#  ('2019-October-Monday', '04:20 pm', 2, 0, 'Female', 23, 'Full'),
#  ('2019-October-Monday', '01:00 pm', 1, 0, 'Male', 58, 'Full'),
#  ('2019-October-Monday', '01:00 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-October-Friday', '11:00 am', 1, 0, 'Male', 63, 'Full'),
#  ('2019-October-Friday', '11:00 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-October-Friday', '08:30 am', 1, 0, 'Female', 31, 'Full'),
#  ('2019-October-Friday', '08:30 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-October-Friday', '03:00 pm', 1, 0, '', '', ''),
#  ('2019-October-Friday', '03:00 pm', 2, 0, 'Male', 28, 'Full'),
#  ('2019-October-Friday', '02:30 pm', 1, 0, 'Male', 38, 'Full'),
#  ('2019-October-Friday', '02:30 pm', 2, 0, 'Female', 23, 'Full'),
#  ('2019-November-Wednesday', '10:44 am', 1, 0, 'Male', 24, 'Full'),
#  ('2019-November-Wednesday', '10:44 am', 2, 0, 'Male', 58, 'Full'),
#  ('2019-November-Wednesday', '09:46 am', 1, 1, 'Male', 52, 'Full'),
#  ('2019-November-Wednesday', '09:46 am', 2, 1, 'Female', 39, 'Full'),
#  ('2019-November-Wednesday', '08:56 am', 1, 0, 'Male', 61, 'Full'),
#  ('2019-November-Wednesday', '08:56 am', 2, 0, 'Male', 25, 'Provisional 2'),
#  ('2019-November-Wednesday', '07:31 pm', 1, 0, 'Male', 26, 'Full'),
#  ('2019-November-Wednesday', '07:31 pm', 2, 0, 'Male', 45, 'Full'),
#  ('2019-November-Wednesday', '07:30 am', 1, 0, 'Male', 24, 'Unlicenced'),
#  ('2019-November-Wednesday', '07:30 am', 2, 0, 'Male', 33, 'Full'),
#  ('2019-November-Wednesday', '06:00 pm', 1, 0, 'Female', 42, 'Full'),
#  ('2019-November-Wednesday', '06:00 pm', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-November-Tuesday', '05:30 pm', 1, 0, 'Male', 41, ''),
#  ('2019-November-Tuesday', '05:30 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-November-Tuesday', '05:30 pm', 3, 0, 'Female', 38, ''),
#  ('2019-November-Tuesday', '05:30 pm', 1, 0, 'Male', 43, 'Full'),
#  ('2019-November-Tuesday', '05:30 pm', 2, 1, 'Male', 35, ''),
#  ('2019-November-Tuesday', '04:30 pm', 1, 1, 'Female', 32, ''),
#  ('2019-November-Tuesday', '03:30 pm', 1, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-November-Tuesday', '03:30 pm', 2, 0, '', '', ''),
#  ('2019-November-Tuesday', '02:00 pm', 1, 1, 'Male', 53, ''),
#  ('2019-November-Tuesday', '02:00 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-November-Thursday', '08:01 am', 1, 0, 'Male', 31, 'Full'),
#  ('2019-November-Thursday', '08:01 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-November-Thursday', '05:50 pm', 1, 0, 'Female', 22, 'Full'),
#  ('2019-November-Thursday', '05:50 pm', 2, 0, 'Male', 44, 'Full'),
#  ('2019-November-Thursday', '05:15 pm', 1, 0, 'Male', 59, 'Full'),
#  ('2019-November-Thursday', '05:15 pm', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-November-Thursday', '04:10 pm', 1, 1, 'Male', 43, 'Full'),
#  ('2019-November-Thursday', '04:10 pm', 2, 0, 'Male', 34, 'Full'),
#  ('2019-November-Thursday', '01:40 pm', 1, 0, 'Female', 26, ''),
#  ('2019-November-Thursday', '01:40 pm', 2, 0, 'Female', 42, 'Full'),
#  ('2019-November-Thursday', '01:20 pm', 1, 1, 'Male', 33, ''),
#  ('2019-November-Sunday', '12:30 pm', 1, 0, 'Male', 23, 'Full'),
#  ('2019-November-Sunday', '10:05 pm', 1, 1, 'Male', 34, ''),
#  ('2019-November-Sunday', '10:05 pm', 2, 0, 'Male', 53, 'Full'),
#  ('2019-November-Sunday', '06:10 pm', 1, 0, 'Male', 56, 'Full'),
#  ('2019-November-Sunday', '06:10 pm', 2, 0, 'Female', 70, 'Full'),
#  ('2019-November-Sunday', '06:00 pm', 1, 0, 'Male', 49, 'Full'),
#  ('2019-November-Sunday', '06:00 pm', 2, 0, 'Female', 25, 'Full'),
#  ('2019-November-Sunday', '05:15 pm', 1, 0, 'Male', 19, 'Provisional 2'),
#  ('2019-November-Sunday', '05:15 pm', 2, 0, 'Male', 43, 'Provisional 2'),
#  ('2019-November-Sunday', '02:00 am', 1, 0, 'Male', 19, 'Provisional 2'),
#  ('2019-November-Sunday', '02:00 am', 2, 0, '', '', ''),
#  ('2019-November-Saturday', '12:45 pm', 1, 0, 'Male', 22, 'Provisional 2'),
#  ('2019-November-Saturday', '12:45 pm', 2, 0, 'Female', 26, 'Full'),
#  ('2019-November-Saturday', '11:19 pm', 1, 0, 'Male', 72, 'Full'),
#  ('2019-November-Saturday', '11:19 pm', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-November-Saturday', '11:15 pm', 1, 0, 'Female', 51, 'Full'),
#  ('2019-November-Saturday', '11:15 pm', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-November-Saturday', '09:25 pm', 1, 0, 'Male', 42, 'Full'),
#  ('2019-November-Saturday', '09:25 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-November-Saturday', '05:25 pm', 1, 0, 'Female', 18, 'Learners'),
#  ('2019-November-Saturday', '05:25 pm', 2, 0, 'Male', 18, 'Provisional 2'),
#  ('2019-November-Saturday', '05:20 pm', 1, 0, 'Female', 67, 'Full'),
#  ('2019-November-Saturday', '05:20 pm', 2, 1, 'Male', 26, ''),
#  ('2019-November-Saturday', '04:59 pm', 1, 0, 'Male', 61, 'Full'),
#  ('2019-November-Saturday', '04:59 pm', 2, 0, 'Male', 62, 'Full'),
#  ('2019-November-Saturday', '04:59 pm', 3, 0, 'Male', 48, 'Full'),
#  ('2019-November-Monday', '12:10 pm', 1, 0, 'Male', 37, 'Full'),
#  ('2019-November-Monday', '12:10 pm', 2, 1, 'Female', 77, ''),
#  ('2019-November-Monday', '08:15 am', 1, 1, 'Male', 40, ''),
#  ('2019-November-Monday', '08:15 am', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-November-Monday', '07:12 pm', 1, 0, 'Male', 33, 'Full'),
#  ('2019-November-Monday', '07:12 pm', 2, 0, 'Male', 25, 'Full'),
#  ('2019-November-Monday', '03:10 am', 1, 0, 'Female', 54, 'Full'),
#  ('2019-November-Monday', '03:10 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-November-Monday', '02:21 pm', 1, 0, 'Male', 21, 'Provisional 2'),
#  ('2019-November-Monday', '02:21 pm', 2, 1, 'Female', 37, ''),
#  ('2019-November-Friday', '12:00 am', 1, 0, 'Male', 23, 'Full'),
#  ('2019-November-Friday', '12:00 am', 2, 0, 'Male', 27, 'Full'),
#  ('2019-November-Friday', '10:05 pm', 1, 0, 'Male', 46, 'Full'),
#  ('2019-November-Friday', '10:05 pm', 2, 0, '', '', ''),
#  ('2019-November-Friday', '10:05 pm', 3, 0, '', '', ''),
#  ('2019-November-Friday', '09:33 am', 1, 1, 'Male', 49, 'Full'),
#  ('2019-November-Friday', '09:33 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-November-Friday', '06:30 pm', 1, 0, 'Female', 25, 'Full'),
#  ('2019-November-Friday', '06:30 pm', 2, 0, 'Female', 25, 'Full'),
#  ('2019-November-Friday', '05:40 pm', 1, 0, 'Female', 48, 'Full'),
#  ('2019-November-Friday', '05:40 pm', 2, 1, 'Male', 25, ''),
#  ('2019-November-Friday', '05:15 pm', 1, 0, 'Male', 57, 'Full'),
#  ('2019-November-Friday', '05:15 pm', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-November-Friday', '04:46 pm', 1, 0, 'Male', 53, 'Full'),
#  ('2019-November-Friday', '04:46 pm', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-November-Friday', '02:42 pm', 1, 1, 'Male', 69, 'Full'),
#  ('2019-November-Friday', '02:42 pm', 2, 0, 'Male', 38, 'Full'),
#  ('2019-May-Wednesday', '10:00 pm', 1, 0, 'Male', 40, 'Full'),
#  ('2019-May-Wednesday', '10:00 pm', 2, 0, 'Female', 49, 'Learners'),
#  ('2019-May-Wednesday', '09:40 am', 1, 0, 'Female', 40, 'Full'),
#  ('2019-May-Wednesday', '09:40 am', 2, 1, 'Male', 34, 'Full'),
#  ('2019-May-Wednesday', '07:00 am', 1, 0, 'Male', 25, 'Full'),
#  ('2019-May-Wednesday', '07:00 am', 2, 1, 'Male', 49, 'Full'),
#  ('2019-May-Wednesday', '06:30 pm', 1, 0, 'Female', 25, 'Full'),
#  ('2019-May-Wednesday', '06:30 pm', 2, 1, 'Male', 31, ''),
#  ('2019-May-Wednesday', '06:05 pm', 1, 0, 'Male', 49, 'Full'),
#  ('2019-May-Wednesday', '06:05 pm', 2, 1, 'Female', 27, 'Full'),
#  ('2019-May-Wednesday', '04:00 pm', 1, 0, 'Female', 41, 'Full'),
#  ('2019-May-Wednesday', '04:00 pm', 2, 0, 'Male', 55, 'Full'),
#  ('2019-May-Wednesday', '04:00 pm', 3, 0, 'Male', 42, 'Full'),
#  ('2019-May-Wednesday', '04:00 pm', 4, 0, 'Male', 39, 'Full'),
#  ('2019-May-Tuesday', '10:25 am', 1, 0, 'Male', 63, 'Full'),
#  ('2019-May-Tuesday', '10:25 am', 2, 0, 'Male', 22, ''),
#  ('2019-May-Tuesday', '08:45 am', 1, 0, 'Female', 24, 'Full'),
#  ('2019-May-Tuesday', '08:45 am', 2, 0, 'Female', 58, 'Full'),
#  ('2019-May-Tuesday', '06:05 pm', 1, 0, 'Female', 39, 'Full'),
#  ('2019-May-Tuesday', '06:05 pm', 2, 0, 'Female', 27, ''),
#  ('2019-May-Tuesday', '04:45 pm', 1, 1, 'Male', 75, 'Full'),
#  ('2019-May-Tuesday', '04:45 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-May-Tuesday', '04:05 pm', 1, 0, 'Male', 37, 'Unknown'),
#  ('2019-May-Tuesday', '04:05 pm', 2, 0, 'Male', 47, 'Unknown'),
#  ('2019-May-Thursday', '12:05 pm', 1, 0, 'Female', 67, 'Full'),
#  ('2019-May-Thursday', '12:05 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-May-Thursday', '09:21 am', 1, 0, 'Male', 34, 'Full'),
#  ('2019-May-Thursday', '09:21 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-May-Thursday', '08:55 pm', 1, 0, 'Male', 21, 'Provisional 1 '),
#  ('2019-May-Thursday', '08:55 pm', 2, 1, 'Female', 57, ''),
#  ('2019-May-Thursday', '08:50 am', 1, 0, '', '', ''),
#  ('2019-May-Thursday', '08:50 am', 2, 0, 'Male', 41, 'Full'),
#  ('2019-May-Thursday', '06:00 pm', 1, 0, 'Male', 20, 'Full'),
#  ('2019-May-Thursday', '06:00 pm', 2, 0, 'Male', 23, 'Full'),
#  ('2019-May-Thursday', '05:49 am', 1, 0, 'Male', 40, 'Full'),
#  ('2019-May-Thursday', '05:49 am', 2, 0, 'Male', 36, 'Full'),
#  ('2019-May-Thursday', '05:46 pm', 1, 0, 'Male', 49, 'Full'),
#  ('2019-May-Thursday', '05:46 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-May-Thursday', '05:40 am', 1, 0, 'Male', 31, 'Full'),
#  ('2019-May-Thursday', '05:40 am', 2, 0, '', '', ''),
#  ('2019-May-Thursday', '05:37 pm', 1, 0, 'Male', 27, 'Full'),
#  ('2019-May-Thursday', '05:37 pm', 2, 0, 'Female', 22, 'Provisional 1 '),
#  ('2019-May-Thursday', '05:37 pm', 3, 0, 'Female', 19, 'Provisional 1 '),
#  ('2019-May-Thursday', '05:00 pm', 1, 0, 'Male', 32, 'Full'),
#  ('2019-May-Thursday', '05:00 pm', 2, 0, 'Male', 36, 'Full'),
#  ('2019-May-Sunday', '05:10 pm', 1, 0, 'Male', 34, 'Full'),
#  ('2019-May-Sunday', '05:10 pm', 2, 1, 'Male', 53, ''),
#  ('2019-May-Saturday', '12:59 am', 1, 0, 'Male', 25, 'Provisional 2'),
#  ('2019-May-Saturday', '12:59 am', 2, 0, '', '', ''),
#  ('2019-May-Saturday', '05:30 pm', 1, 0, 'Male', 18, 'Learners'),
#  ('2019-May-Saturday', '05:30 pm', 2, 0, 'Female', 64, 'Full'),
#  ('2019-May-Saturday', '04:10 pm', 1, 0, 'Male', 43, 'Full'),
#  ('2019-May-Saturday', '04:10 pm', 2, 1, 'Male', 15, ''),
#  ('2019-May-Saturday', '01:40 am', 1, 0, 'Male', 52, 'Full'),
#  ('2019-May-Saturday', '01:40 am', 2, 0, '', '', ''),
#  ('2019-May-Monday', '08:45 am', 1, 0, 'Male', 36, 'Full'),
#  ('2019-May-Monday', '08:45 am', 2, 1, 'Male', 53, 'Full'),
#  ('2019-May-Monday', '08:00 am', 1, 0, 'Male', 50, 'Full'),
#  ('2019-May-Monday', '08:00 am', 2, 0, '', '', ''),
#  ('2019-May-Monday', '06:40 am', 1, 0, 'Male', 45, 'Full'),
#  ('2019-May-Monday', '06:40 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-May-Monday', '01:45 pm', 1, 0, 'Male', 48, 'Full'),
#  ('2019-May-Monday', '01:45 pm', 2, 0, '', '', ''),
#  ('2019-May-Friday', '11:40 pm', 1, 0, 'Male', 34, 'Full'),
#  ('2019-May-Friday', '11:40 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-May-Friday', '08:38 am', 1, 0, 'Male', 46, 'Full'),
#  ('2019-May-Friday', '08:38 am', 2, 1, 'Female', 51, ''),
#  ('2019-May-Friday', '07:51 pm', 1, 1, 'Male', 31, 'Full'),
#  ('2019-May-Friday', '07:40 am', 1, 0, 'Male', 45, 'Full'),
#  ('2019-May-Friday', '07:40 am', 2, 1, 'Male', 58, ''),
#  ('2019-May-Friday', '06:31 pm', 1, 0, 'Male', 17, 'Learners'),
#  ('2019-May-Friday', '06:31 pm', 2, 0, 'Female', 39, 'Full'),
#  ('2019-May-Friday', '05:40 pm', 1, 1, 'Male', 34, ''),
#  ('2019-May-Friday', '05:40 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-May-Friday', '05:22 pm', 1, 0, 'Female', 21, ''),
#  ('2019-May-Friday', '05:22 pm', 2, 0, 'Female', 55, 'Full'),
#  ('2019-May-Friday', '05:15 pm', 1, 0, 'Male', 25, 'Full'),
#  ('2019-May-Friday', '05:15 pm', 2, 0, 'Male', 39, 'Full'),
#  ('2019-May-Friday', '03:30 pm', 1, 0, 'Female', 27, 'Full'),
#  ('2019-May-Friday', '03:30 pm', 2, 0, 'Male', 40, 'Full'),
#  ('2019-May-Friday', '03:00 pm', 1, 0, 'Male', 31, 'Full'),
#  ('2019-May-Friday', '03:00 pm', 2, 0, 'Male', 67, 'Full'),
#  ('2019-May-Friday', '02:00 pm', 1, 0, 'Male', 38, 'Full'),
#  ('2019-May-Friday', '02:00 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-March-Wednesday', '08:23 am', 1, 2, 'Female', 39, 'Full'),
#  ('2019-March-Wednesday', '08:23 am', 2, 0, 'Male', 23, 'Probationary'),
#  ('2019-March-Wednesday', '08:10 am', 1, 0, 'Female', 21, 'Full'),
#  ('2019-March-Wednesday', '08:10 am', 2, 1, 'Male', 62, ''),
#  ('2019-March-Wednesday', '06:10 pm', 1, 0, 'Male', 45, 'Full'),
#  ('2019-March-Wednesday', '06:10 pm', 2, 0, 'Male', 26, 'Unlicenced'),
#  ('2019-March-Wednesday', '05:27 pm', 1, 0, 'Female', 35, 'Full'),
#  ('2019-March-Wednesday', '05:27 pm', 2, 1, 'Male', 49, ''),
#  ('2019-March-Tuesday', '09:00 am', 1, 0, 'Female', 40, 'Full'),
#  ('2019-March-Tuesday', '09:00 am', 2, 0, 'Male', 57, 'Full'),
#  ('2019-March-Tuesday', '08:20 am', 1, 0, 'Male', 61, 'Unknown'),
#  ('2019-March-Tuesday', '08:20 am', 2, 0, 'Female', 40, 'Full'),
#  ('2019-March-Tuesday', '08:20 am', 1, 0, 'Female', 36, ''),
#  ('2019-March-Tuesday', '08:20 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-March-Tuesday', '06:16 pm', 1, 0, 'Female', 29, 'Full'),
#  ('2019-March-Tuesday', '06:16 pm', 2, 1, 'Male', 24, ''),
#  ('2019-March-Tuesday', '06:09 pm', 1, 2, 'Female', 20, 'Full'),
#  ('2019-March-Tuesday', '06:09 pm', 2, 0, 'Male', 19, 'Provisional 2'),
#  ('2019-March-Tuesday', '05:40 pm', 1, 0, 'Male', 50, 'Full'),
#  ('2019-March-Tuesday', '05:40 pm', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-March-Tuesday', '05:20 pm', 1, 1, 'Female', 44, ''),
#  ('2019-March-Tuesday', '05:20 pm', 2, 0, 'Male', 49, 'Full'),
#  ('2019-March-Tuesday', '05:20 pm', 1, 0, 'Female', 48, 'Full'),
#  ('2019-March-Tuesday', '05:20 pm', 2, 0, 'Male', 35, 'Full'),
#  ('2019-March-Tuesday', '05:20 pm', 3, 0, 'Female', 63, 'Full'),
#  ('2019-March-Tuesday', '05:20 pm', 4, 0, 'Male', 42, 'Full'),
#  ('2019-March-Tuesday', '03:50 pm', 1, 0, 'Male', 30, 'Full'),
#  ('2019-March-Tuesday', '03:50 pm', 2, 0, 'Male', 68, 'Full'),
#  ('2019-March-Tuesday', '01:55 pm', 1, 1, 'Male', 43, 'Full'),
#  ('2019-March-Tuesday', '01:55 pm', 2, 0, 'Male', 37, 'Full'),
#  ('2019-March-Tuesday', '01:55 pm', 3, 0, 'Male', 60, 'Full'),
#  ('2019-March-Tuesday', '01:55 pm', 4, 0, 'Male', 84, 'Full'),
#  ('2019-March-Thursday', '11:15 am', 1, 0, 'Male', 63, 'Full'),
#  ('2019-March-Thursday', '11:15 am', 2, 0, 'Female', 2, ''),
#  ('2019-March-Thursday', '07:53 am', 1, 0, 'Male', 38, 'Full'),
#  ('2019-March-Thursday', '07:53 am', 2, 0, 'Male', 26, 'Full'),
#  ('2019-March-Thursday', '07:20 am', 1, 1, 'Male', 47, 'Full'),
#  ('2019-March-Thursday', '07:20 am', 2, 1, 'Male', 33, 'Full'),
#  ('2019-March-Thursday', '07:20 am', 3, 0, 'Male', 45, 'Full'),
#  ('2019-March-Thursday', '06:40 pm', 1, 0, 'Male', 26, 'Full'),
#  ('2019-March-Thursday', '06:40 pm', 2, 1, 'Female', 60, ''),
#  ('2019-March-Thursday', '05:55 pm', 1, 1, 'Male', 'XXX', ''),
#  ('2019-March-Thursday', '05:55 pm', 2, 0, 'Male', 39, 'Full'),
#  ('2019-March-Thursday', '04:55 pm', 1, 0, 'Female', 34, 'Full'),
#  ('2019-March-Thursday', '04:55 pm', 2, 0, 'Male', 57, ''),
#  ('2019-March-Thursday', '04:05 pm', 1, 0, 'Female', 34, 'Full'),
#  ('2019-March-Thursday', '04:05 pm', 2, 0, 'Male', 46, 'Full'),
#  ('2019-March-Sunday', '07:15 am', 1, 0, '', '', ''),
#  ('2019-March-Sunday', '07:15 am', 2, 1, 'Male', 23, ''),
#  ('2019-March-Sunday', '02:45 pm', 1, 0, 'Female', 41, 'Full'),
#  ('2019-March-Sunday', '02:45 pm', 2, 0, 'Female', 55, 'Full'),
#  ('2019-March-Saturday', '11:50 am', 1, 1, 'Female', 36, 'Full'),
#  ('2019-March-Saturday', '11:50 am', 2, 0, 'Male', 42, 'Full'),
#  ('2019-March-Saturday', '11:20 am', 1, 0, 'Male', 36, 'Full'),
#  ('2019-March-Saturday', '11:20 am', 2, 0, 'Male', 25, 'Full'),
#  ('2019-March-Saturday', '11:20 am', 3, 0, 'Male', 35, 'Full'),
#  ('2019-March-Saturday', '11:00 pm', 1, 0, 'Female', 24, 'Full'),
#  ('2019-March-Saturday', '11:00 pm', 2, 0, 'Male', 27, ''),
#  ('2019-March-Saturday', '10:40 am', 1, 0, 'Male', 46, 'Full'),
#  ('2019-March-Saturday', '10:40 am', 2, 1, 'Unknown', 'XXX', ''),
#  ('2019-March-Saturday', '10:40 am', 3, 0, 'Male', 60, ''),
#  ('2019-March-Saturday', '08:45 pm', 1, 1, 'Male', 32, 'Full'),
#  ('2019-March-Saturday', '08:45 pm', 2, 1, 'Male', 28, 'Full'),
#  ('2019-March-Saturday', '07:41 am', 1, 0, 'Male', 26, 'Full'),
#  ('2019-March-Saturday', '07:41 am', 2, 0, 'Male', 25, ''),
#  ('2019-March-Saturday', '03:41 pm', 1, 0, 'Male', 18, 'Provisional 2'),
#  ('2019-March-Saturday', '03:41 pm', 2, 0, 'Male', 26, 'Full'),
#  ('2019-March-Saturday', '03:41 pm', 3, 0, 'Male', 45, 'Full'),
#  ('2019-March-Saturday', '03:35 am', 1, 0, 'Female', 27, 'Full'),
#  ('2019-March-Saturday', '03:35 am', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-March-Saturday', '03:30 pm', 1, 0, 'Male', 28, 'Unlicenced'),
#  ('2019-March-Saturday', '03:30 pm', 2, 0, 'Male', 54, 'Full'),
#  ('2019-March-Saturday', '02:20 pm', 1, 0, 'Male', 26, 'Full'),
#  ('2019-March-Saturday', '02:20 pm', 2, 0, 'Female', 76, 'Full'),
#  ('2019-March-Saturday', '02:00 pm', 1, 0, 'Female', 43, 'Full'),
#  ('2019-March-Saturday', '02:00 pm', 2, 0, 'Male', 29, 'Full'),
#  ('2019-March-Saturday', '01:45 pm', 1, 1, 'Male', 24, ''),
#  ('2019-March-Saturday', '01:45 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-March-Saturday', '01:30 pm', 1, 0, 'Female', 18, 'Provisional 1 '),
#  ('2019-March-Saturday', '01:30 pm', 2, 0, 'Male', 59, 'Full'),
#  ('2019-March-Monday', '09:55 am', 1, 0, 'Female', 23, 'Full'),
#  ('2019-March-Monday', '09:55 am', 2, 1, 'Male', 'XXX', ''),
#  ('2019-March-Monday', '08:40 am', 1, 0, 'Male', 50, ''),
#  ('2019-March-Monday', '08:40 am', 2, 0, 'Female', 37, 'Full'),
#  ('2019-March-Monday', '08:05 am', 1, 0, 'Male', 25, 'Full'),
#  ('2019-March-Monday', '08:05 am', 2, 0, 'Male', 44, 'Full'),
#  ('2019-March-Monday', '05:50 pm', 1, 0, 'Male', 77, 'Full'),
#  ('2019-March-Monday', '05:50 pm', 2, 0, 'Male', 62, 'Full'),
#  ('2019-March-Monday', '04:25 pm', 1, 0, 'Female', 20, 'Provisional 2'),
#  ('2019-March-Monday', '04:25 pm', 2, 0, 'Male', 63, 'Full'),
#  ('2019-March-Friday', '12:30 pm', 1, 1, 'Male', 20, ''),
#  ('2019-March-Friday', '12:30 pm', 2, 0, 'Male', 56, 'Full'),
#  ('2019-March-Friday', '12:00 pm', 1, 0, 'Male', 31, 'Full'),
#  ('2019-March-Friday', '12:00 pm', 2, 0, '', '', ''),
#  ('2019-March-Friday', '09:30 pm', 1, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-March-Friday', '09:30 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-March-Friday', '09:30 pm', 3, 0, 'Female', 32, 'Full'),
#  ('2019-March-Friday', '06:35 pm', 1, 1, 'Male', 30, ''),
#  ('2019-March-Friday', '06:30 pm', 1, 0, 'Female', 28, 'Full'),
#  ('2019-March-Friday', '06:30 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-March-Friday', '05:52 pm', 1, 0, 'Male', 27, 'Full'),
#  ('2019-March-Friday', '05:52 pm', 2, 0, 'Female', 66, 'Full'),
#  ('2019-March-Friday', '05:52 pm', 3, 1, 'Female', 58, 'Full'),
#  ('2019-March-Friday', '05:30 pm', 1, 0, '', '', ''),
#  ('2019-March-Friday', '05:30 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-March-Friday', '03:30 pm', 1, 1, 'Male', 55, 'Full'),
#  ('2019-March-Friday', '03:30 pm', 2, 0, '', '', ''),
#  ('2019-March-Friday', '02:00 pm', 1, 1, 'Male', 24, 'Full'),
#  ('2019-March-Friday', '02:00 pm', 2, 0, 'Male', 69, 'Full'),
#  ('2019-June-Wednesday', '08:10 am', 1, 0, 'Male', 56, 'Full'),
#  ('2019-June-Wednesday', '08:10 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-June-Wednesday', '06:39 am', 1, 0, 'Female', 30, 'Full'),
#  ('2019-June-Wednesday', '06:39 am', 2, 1, 'Male', 60, 'Full'),
#  ('2019-June-Wednesday', '05:55 pm', 1, 0, 'Male', 27, 'Full'),
#  ('2019-June-Wednesday', '05:55 pm', 2, 0, 'Female', 37, 'Full'),
#  ('2019-June-Wednesday', '05:55 pm', 3, 0, 'Female', 36, 'Full'),
#  ('2019-June-Wednesday', '03:15 pm', 1, 0, 'Female', 53, 'Full'),
#  ('2019-June-Wednesday', '03:15 pm', 2, 1, 'Female', 27, ''),
#  ('2019-June-Wednesday', '01:35 pm', 1, 1, 'Male', 44, 'Full'),
#  ('2019-June-Wednesday', '01:35 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-June-Tuesday', '09:25 am', 1, 0, 'Female', 31, 'Full'),
#  ('2019-June-Tuesday', '09:25 am', 2, 0, 'Male', 40, 'Full'),
#  ('2019-June-Tuesday', '09:00 am', 1, 0, 'Male', 76, 'Full'),
#  ('2019-June-Tuesday', '09:00 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-June-Tuesday', '06:30 pm', 1, 0, 'Female', 49, 'Full'),
#  ('2019-June-Tuesday', '06:30 pm', 2, 1, 'Male', 20, ''),
#  ('2019-June-Tuesday', '02:00 pm', 1, 0, 'Male', 29, 'Full'),
#  ('2019-June-Tuesday', '02:00 pm', 2, 1, 'Female', 34, 'Full'),
#  ('2019-June-Thursday', '12:20 pm', 1, 0, 'Female', 72, 'Full'),
#  ('2019-June-Thursday', '12:20 pm', 2, 1, 'Female', 19, ''),
#  ('2019-June-Thursday', '10:25 pm', 1, 0, 'Male', 32, 'Full'),
#  ('2019-June-Thursday', '10:25 pm', 2, 0, '', '', ''),
#  ('2019-June-Thursday', '10:00 am', 1, 0, 'Female', 38, 'Full'),
#  ('2019-June-Thursday', '10:00 am', 2, 1, 'Male', 42, ''),
#  ('2019-June-Thursday', '09:15 pm', 1, 0, 'Male', 57, 'Full'),
#  ('2019-June-Thursday', '09:15 pm', 2, 1, 'Male', 58, 'Full'),
#  ('2019-June-Thursday', '07:55 am', 1, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-June-Thursday', '07:55 am', 2, 0, 'Male', 30, 'Full'),
#  ('2019-June-Thursday', '06:00 pm', 1, 0, 'Male', 45, ''),
#  ('2019-June-Thursday', '06:00 pm', 2, 0, 'Male', 21, 'Provisional 2'),
#  ('2019-June-Thursday', '05:55 pm', 1, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-June-Thursday', '05:55 pm', 2, 0, 'Female', 41, ''),
#  ('2019-June-Thursday', '05:41 pm', 1, 0, 'Female', 60, 'Full'),
#  ('2019-June-Thursday', '05:41 pm', 2, 0, 'Male', 45, 'Full'),
#  ('2019-June-Thursday', '05:40 pm', 1, 0, 'Male', 49, 'Full'),
#  ('2019-June-Thursday', '05:40 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-June-Thursday', '05:21 pm', 1, 0, 'Male', 51, 'Full'),
#  ('2019-June-Thursday', '05:21 pm', 2, 0, 'Male', 37, 'Probationary'),
#  ('2019-June-Thursday', '02:43 pm', 1, 0, 'Male', 38, 'Full'),
#  ('2019-June-Thursday', '02:43 pm', 2, 0, 'Male', 74, 'Full'),
#  ('2019-June-Thursday', '02:34 pm', 1, 0, 'Male', 26, 'Full'),
#  ('2019-June-Thursday', '02:34 pm', 2, 0, 'Male', 24, ''),
#  ('2019-June-Thursday', '02:00 pm', 1, 0, 'Male', 61, 'Full'),
#  ('2019-June-Thursday', '02:00 pm', 2, 0, 'Female', 37, 'Full'),
#  ('2019-June-Sunday', '03:00 pm', 1, 0, 'Female', 57, 'Full'),
#  ('2019-June-Sunday', '03:00 pm', 2, 0, 'Male', 32, 'Full'),
#  ('2019-June-Saturday', '05:15 pm', 1, 0, 'Female', 33, 'Full'),
#  ('2019-June-Saturday', '05:15 pm', 2, 0, 'Female', 22, ''),
#  ('2019-June-Saturday', '03:20 pm', 1, 0, 'Male', 27, 'Provisional 2'),
#  ('2019-June-Saturday', '03:20 pm', 2, 0, 'Male', 41, 'Full'),
#  ('2019-June-Saturday', '01:05 pm', 1, 0, 'Male', 43, 'Full'),
#  ('2019-June-Saturday', '01:05 pm', 2, 0, 'Male', 24, 'Unlicenced'),
#  ('2019-June-Monday', '10:00 am', 1, 0, 'Female', 55, 'Full'),
#  ('2019-June-Monday', '10:00 am', 2, 1, 'Female', 63, ''),
#  ('2019-June-Monday', '08:04 pm', 1, 1, 'Male', 39, 'Full'),
#  ('2019-June-Monday', '08:04 pm', 2, 0, 'Male', 20, 'Unlicenced'),
#  ('2019-June-Monday', '05:45 pm', 1, 0, 'Male', 28, 'Full'),
#  ('2019-June-Monday', '05:45 pm', 2, 0, 'Male', 88, ''),
#  ('2019-June-Monday', '05:20 pm', 1, 1, 'Female', 54, 'Full'),
#  ('2019-June-Monday', '05:20 pm', 2, 0, 'Male', 18, 'Provisional 1 '),
#  ('2019-June-Monday', '04:29 pm', 1, 0, 'Male', 35, 'Full'),
#  ('2019-June-Monday', '04:29 pm', 2, 1, 'Male', 32, ''),
#  ('2019-June-Friday', '12:30 pm', 1, 0, 'Male', 38, 'Full'),
#  ('2019-June-Friday', '12:30 pm', 2, 0, 'Male', 53, ''),
#  ('2019-June-Friday', '10:45 pm', 1, 0, 'Male', 32, 'Full'),
#  ('2019-June-Friday', '10:45 pm', 2, 0, 'Male', 22, 'Full'),
#  ('2019-June-Friday', '09:32 pm', 1, 0, 'Male', 50, 'Full'),
#  ('2019-June-Friday', '09:32 pm', 2, 0, 'Female', 55, 'Full'),
#  ('2019-June-Friday', '05:05 pm', 1, 0, 'Male', 70, 'Full'),
#  ('2019-June-Friday', '05:05 pm', 2, 0, 'Male', 30, 'Full'),
#  ('2019-June-Friday', '04:00 pm', 1, 0, 'Male', 36, 'Full'),
#  ('2019-June-Friday', '04:00 pm', 2, 0, 'Male', 58, 'Full'),
#  ('2019-June-Friday', '01:20 pm', 1, 0, 'Male', 48, 'Full'),
#  ('2019-June-Friday', '01:20 pm', 2, 0, 'Male', 36, 'Full'),
#  ('2019-July-Wednesday', '12:30 pm', 1, 1, 'Male', 53, ''),
#  ('2019-July-Wednesday', '12:30 pm', 2, 0, 'Male', 73, 'Full'),
#  ('2019-July-Wednesday', '09:22 am', 1, 0, 'Male', 63, 'Full'),
#  ('2019-July-Wednesday', '09:22 am', 2, 0, 'Male', 20, 'Full'),
#  ('2019-July-Wednesday', '08:40 am', 1, 0, 'Male', 44, 'Full'),
#  ('2019-July-Wednesday', '08:40 am', 2, 0, 'Female', 44, 'Full'),
#  ('2019-July-Wednesday', '07:49 pm', 1, 0, 'Female', 19, 'Provisional 2'),
#  ('2019-July-Wednesday', '07:49 pm', 2, 0, 'Male', 30, 'Full'),
#  ('2019-July-Wednesday', '06:15 pm', 1, 0, 'Female', 28, 'Full'),
#  ('2019-July-Wednesday', '06:15 pm', 2, 1, 'Female', 28, ''),
#  ('2019-July-Wednesday', '04:48 pm', 1, 0, 'Female', 37, 'Full'),
#  ('2019-July-Wednesday', '04:48 pm', 2, 0, 'Male', 45, 'Full'),
#  ('2019-July-Wednesday', '04:48 pm', 3, 0, 'Male', 47, 'Full'),
#  ('2019-July-Wednesday', '04:40 pm', 1, 0, 'Male', 27, 'Full'),
#  ('2019-July-Wednesday', '04:40 pm', 2, 1, 'Female', 23, ''),
#  ('2019-July-Wednesday', '04:08 pm', 1, 0, 'Male', 36, 'Full'),
#  ('2019-July-Wednesday', '04:08 pm', 2, 1, 'Male', 46, ''),
#  ('2019-July-Wednesday', '03:45 pm', 1, 0, 'Male', 50, 'Full'),
#  ('2019-July-Wednesday', '03:45 pm', 2, 0, 'Male', 42, 'Full'),
#  ('2019-July-Tuesday', '11:30 am', 1, 1, 'Female', 43, 'Full'),
#  ('2019-July-Tuesday', '11:30 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-July-Tuesday', '11:00 am', 1, 0, 'Male', 33, 'Unlicenced'),
#  ('2019-July-Tuesday', '11:00 am', 2, 0, '', '', ''),
#  ('2019-July-Tuesday', '11:00 am', 3, 0, '', '', ''),
#  ('2019-July-Tuesday', '06:07 pm', 1, 1, 'Male', 25, ''),
#  ('2019-July-Tuesday', '06:07 pm', 2, 0, 'Male', 28, 'Full'),
#  ('2019-July-Tuesday', '06:00 pm', 1, 0, 'Female', 41, 'Full'),
#  ('2019-July-Tuesday', '06:00 pm', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-July-Tuesday', '05:30 pm', 1, 0, 'Male', 29, 'Full'),
#  ('2019-July-Tuesday', '05:30 pm', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-July-Tuesday', '04:54 pm', 1, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-July-Tuesday', '04:54 pm', 2, 0, 'Male', 27, 'Full'),
#  ('2019-July-Tuesday', '04:54 pm', 3, 0, 'Male', 29, 'Full'),
#  ('2019-July-Tuesday', '03:00 pm', 1, 0, 'Male', 65, 'Full'),
#  ('2019-July-Tuesday', '03:00 pm', 2, 0, 'Male', 67, 'Full'),
#  ('2019-July-Tuesday', '02:13 pm', 1, 0, 'Unknown', 'XXX', 'Full'),
#  ('2019-July-Tuesday', '02:13 pm', 2, 0, 'Female', 26, 'Full'),
#  ('2019-July-Thursday', '10:00 am', 1, 0, 'Male', 50, 'Full'),
#  ('2019-July-Thursday', '10:00 am', 2, 1, 'Female', 27, ''),
#  ('2019-July-Thursday', '08:54 am', 1, 0, 'Female', 24, 'Full'),
#  ('2019-July-Thursday', '08:54 am', 2, 0, 'Female', 44, 'Full'),
#  ('2019-July-Thursday', '08:45 pm', 1, 0, 'Male', 17, 'Provisional 1 '),
#  ('2019-July-Thursday', '08:45 pm', 2, 1, 'Male', 29, ''),
#  ('2019-July-Thursday', '05:55 pm', 1, 0, 'Female', 48, 'Full'),
#  ('2019-July-Thursday', '05:55 pm', 2, 0, 'Male', 22, ''),
#  ('2019-July-Thursday', '02:30 pm', 1, 0, 'Male', 30, 'Full'),
#  ('2019-July-Thursday', '02:30 pm', 2, 0, 'Female', 38, ''),
#  ('2019-July-Thursday', '02:30 pm', 1, 0, 'Female', 57, 'Full'),
#  ('2019-July-Thursday', '02:30 pm', 2, 0, 'Female', 51, 'Full'),
#  ('2019-July-Sunday', '06:49 pm', 1, 0, 'Male', 28, 'Unlicenced'),
#  ('2019-July-Sunday', '06:49 pm', 2, 0, 'Male', 52, 'Full'),
#  ('2019-July-Sunday', '01:41 pm', 1, 0, 'Male', 36, 'Full'),
#  ('2019-July-Sunday', '01:41 pm', 2, 1, 'Female', 20, ''),
#  ('2019-July-Saturday', '01:00 pm', 1, 0, 'Female', 60, 'Full'),
#  ('2019-July-Saturday', '01:00 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-July-Monday', '11:25 am', 1, 0, 'Male', 41, 'Full'),
#  ('2019-July-Monday', '11:25 am', 2, 1, 'Male', 18, ''),
#  ('2019-July-Monday', '08:30 am', 1, 0, 'Male', 17, ''),
#  ('2019-July-Monday', '08:30 am', 2, 0, 'Male', 22, 'Full'),
#  ('2019-July-Monday', '07:40 pm', 1, 0, 'Male', 34, 'Full'),
#  ('2019-July-Monday', '07:40 pm', 2, 0, 'Male', 55, 'Full'),
#  ('2019-July-Monday', '02:30 pm', 1, 0, 'Female', 23, 'Unknown'),
#  ('2019-July-Monday', '02:30 pm', 2, 0, 'Male', 27, 'Unknown'),
#  ('2019-July-Friday', '12:30 pm', 1, 0, 'Male', 37, 'Full'),
#  ('2019-July-Friday', '12:30 pm', 2, 1, 'Male', 52, ''),
#  ('2019-July-Friday', '12:20 pm', 1, 0, 'Male', 38, 'Full'),
#  ('2019-July-Friday', '12:20 pm', 2, 0, 'Female', 22, 'Unlicenced'),
#  ('2019-July-Friday', '11:45 pm', 1, 0, 'Male', 26, 'Full'),
#  ('2019-July-Friday', '11:45 pm', 2, 1, 'Female', 33, ''),
#  ('2019-July-Friday', '11:00 pm', 1, 1, 'Male', 47, 'Full'),
#  ('2019-July-Friday', '11:00 pm', 2, 0, 'Male', 24, 'Full'),
#  ('2019-July-Friday', '10:30 pm', 1, 0, 'Male', 36, 'Provisional 1 '),
#  ('2019-July-Friday', '10:30 pm', 2, 0, '', '', ''),
#  ('2019-July-Friday', '10:00 pm', 1, 0, 'Male', 82, 'Full'),
#  ('2019-July-Friday', '10:00 pm', 2, 0, '', '', ''),
#  ('2019-July-Friday', '09:45 am', 1, 0, 'Female', 52, ''),
#  ('2019-July-Friday', '09:45 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-July-Friday', '09:40 am', 1, 0, 'Male', 58, 'Full'),
#  ('2019-July-Friday', '09:40 am', 2, 1, 'Male', 61, ''),
#  ('2019-July-Friday', '09:00 am', 1, 0, 'Female', 33, 'Full'),
#  ('2019-July-Friday', '09:00 am', 2, 0, 'Male', 35, 'Full'),
#  ('2019-July-Friday', '08:48 am', 1, 0, 'Male', 58, 'Full'),
#  ('2019-July-Friday', '08:48 am', 2, 0, '', '', ''),
#  ('2019-July-Friday', '08:48 am', 3, 0, '', '', ''),
#  ('2019-July-Friday', '07:35 am', 1, 0, 'Male', 21, 'Full'),
#  ('2019-July-Friday', '07:35 am', 2, 0, 'Male', 19, 'Provisional 2'),
#  ('2019-July-Friday', '07:35 am', 3, 0, 'Male', 55, 'Full'),
#  ('2019-July-Friday', '06:10 pm', 1, 0, 'Female', 22, 'Full'),
#  ('2019-July-Friday', '06:10 pm', 2, 0, 'Female', 30, 'Full'),
#  ('2019-July-Friday', '06:10 pm', 3, 0, 'Male', 57, 'Full'),
#  ('2019-July-Friday', '06:10 pm', 1, 0, 'Male', 25, 'Full'),
#  ('2019-July-Friday', '06:10 pm', 2, 1, 'Male', 30, 'Full'),
#  ('2019-July-Friday', '05:52 pm', 1, 0, 'Male', 37, 'Full'),
#  ('2019-July-Friday', '05:52 pm', 2, 1, 'Female', 44, 'Provisional 2'),
#  ('2019-July-Friday', '03:50 pm', 1, 0, 'Male', 20, 'Full'),
#  ('2019-July-Friday', '03:50 pm', 2, 0, 'Female', 40, 'Full'),
#  ('2019-July-Friday', '03:35 pm', 1, 0, 'Female', 36, 'Full'),
#  ('2019-July-Friday', '03:35 pm', 2, 0, 'Male', 33, 'Full'),
#  ('2019-July-Friday', '03:24 pm', 1, 0, 'Male', 27, 'Full'),
#  ('2019-July-Friday', '03:24 pm', 2, 0, 'Male', 26, 'Full'),
#  ('2019-January-Wednesday', '11:14 am', 1, 0, 'Male', 20, 'Provisional 2'),
#  ('2019-January-Wednesday', '11:14 am', 2, 0, 'Male', 32, 'Full'),
#  ('2019-January-Wednesday', '09:20 am', 1, 0, 'Female', 33, 'Full'),
#  ('2019-January-Wednesday', '09:20 am', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-January-Wednesday', '09:00 am', 1, 0, 'Female', 38, 'Full'),
#  ('2019-January-Wednesday', '09:00 am', 2, 1, 'Female', 40, ''),
#  ('2019-January-Wednesday', '08:15 am', 1, 1, 'Female', 70, ''),
#  ('2019-January-Wednesday', '08:15 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-January-Wednesday', '08:10 pm', 1, 0, 'Male', 26, 'Full'),
#  ('2019-January-Wednesday', '08:10 pm', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-January-Wednesday', '05:00 pm', 1, 1, 'Female', 39, 'Full'),
#  ('2019-January-Wednesday', '05:00 pm', 2, 0, 'Female', 22, 'Full'),
#  ('2019-January-Wednesday', '02:47 pm', 1, 1, 'Male', 44, 'Full'),
#  ('2019-January-Wednesday', '02:47 pm', 2, 1, 'Female', 45, 'Full'),
#  ('2019-January-Tuesday', '10:11 am', 1, 0, 'Male', 39, 'Unknown'),
#  ('2019-January-Tuesday', '10:11 am', 2, 0, 'Male', 44, ''),
#  ('2019-January-Tuesday', '07:00 am', 1, 0, 'Male', 48, 'Full'),
#  ('2019-January-Tuesday', '07:00 am', 2, 0, '', '', ''),
#  ('2019-January-Tuesday', '06:19 pm', 1, 0, 'Male', 44, 'Full'),
#  ('2019-January-Tuesday', '06:19 pm', 2, 0, 'Female', 43, 'Full'),
#  ('2019-January-Tuesday', '04:40 pm', 1, 0, '', '', ''),
#  ('2019-January-Tuesday', '04:40 pm', 2, 0, 'Male', 61, 'Full'),
#  ('2019-January-Tuesday', '04:30 pm', 1, 1, 'Male', 34, 'Full'),
#  ('2019-January-Tuesday', '04:30 pm', 2, 0, 'Male', 44, 'Full'),
#  ('2019-January-Tuesday', '04:30 pm', 1, 1, 'Male', 31, ''),
#  ('2019-January-Tuesday', '04:30 pm', 2, 0, 'Male', 51, 'Full'),
#  ('2019-January-Tuesday', '01:40 pm', 1, 0, 'Female', 66, 'Full'),
#  ('2019-January-Tuesday', '01:40 pm', 2, 0, 'Male', 91, 'Full'),
#  ('2019-January-Thursday', '12:55 pm', 1, 0, 'Male', 19, 'Full'),
#  ('2019-January-Thursday', '12:55 pm', 2, 0, 'Unknown', 'XXX', 'Full'),
#  ('2019-January-Thursday', '12:45 pm', 1, 0, 'Male', 73, 'Full'),
#  ('2019-January-Thursday', '12:45 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-January-Thursday', '12:15 pm', 1, 0, 'Male', 22, 'Full'),
#  ('2019-January-Thursday', '12:15 pm', 2, 0, 'Female', 44, 'Full'),
#  ('2019-January-Thursday', '11:40 am', 1, 1, 'Male', 41, 'Full'),
#  ('2019-January-Thursday', '11:40 am', 2, 0, '', '', ''),
#  ('2019-January-Thursday', '11:40 am', 3, 0, '', '', ''),
#  ('2019-January-Thursday', '11:40 am', 4, 0, '', '', ''),
#  ('2019-January-Thursday', '10:40 pm', 1, 0, 'Female', 22, 'Full'),
#  ('2019-January-Thursday', '10:40 pm', 2, 0, 'Male', 17, 'Provisional 1 '),
#  ('2019-January-Thursday', '08:54 pm', 1, 0, 'Female', 65, 'Full'),
#  ('2019-January-Thursday', '08:54 pm', 2, 1, 'Female', 47, ''),
#  ('2019-January-Thursday', '08:10 am', 1, 0, 'Male', 39, 'Full'),
#  ('2019-January-Thursday', '08:10 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-January-Thursday', '07:15 pm', 1, 0, 'Male', 20, 'Provisional 2'),
#  ('2019-January-Thursday', '07:15 pm', 2, 0, 'Male', 21, 'Full'),
#  ('2019-January-Thursday', '05:30 pm', 1, 0, 'Female', 49, 'Full'),
#  ('2019-January-Thursday', '05:30 pm', 2, 0, 'Male', 25, 'Full'),
#  ('2019-January-Thursday', '05:30 pm', 3, 0, 'Male', 38, 'Full'),
#  ('2019-January-Thursday', '05:20 pm', 1, 0, 'Female', 42, 'Full'),
#  ('2019-January-Thursday', '05:20 pm', 2, 0, 'Female', 47, 'Full'),
#  ('2019-January-Thursday', '05:13 pm', 1, 0, 'Male', 23, 'Full'),
#  ('2019-January-Thursday', '05:13 pm', 2, 1, 'Female', 5, ''),
#  ('2019-January-Thursday', '03:02 am', 1, 0, 'Male', 33, 'Full'),
#  ('2019-January-Thursday', '03:02 am', 2, 0, 'Male', 24, 'Full'),
#  ('2019-January-Thursday', '03:00 pm', 1, 1, 'Female', 61, 'Full'),
#  ('2019-January-Thursday', '03:00 pm', 2, 1, 'Male', 26, 'Full'),
#  ('2019-January-Sunday', '09:55 am', 1, 0, 'Female', 38, 'Full'),
#  ('2019-January-Sunday', '09:55 am', 2, 0, '', '', ''),
#  ('2019-January-Sunday', '04:50 am', 1, 1, 'Female', 'XXX', ''),
#  ('2019-January-Sunday', '04:50 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-January-Sunday', '03:09 pm', 1, 0, 'Female', 43, 'Full'),
#  ('2019-January-Sunday', '03:09 pm', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-January-Saturday', '11:25 pm', 1, 1, 'Male', 47, 'Full'),
#  ('2019-January-Saturday', '02:14 pm', 1, 0, 'Female', 20, 'Provisional 1 '),
#  ('2019-January-Saturday', '02:14 pm', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-January-Saturday', '01:50 pm', 1, 0, 'Female', 39, 'Full'),
#  ('2019-January-Saturday', '01:50 pm', 2, 0, 'Female', 44, ''),
#  ('2019-January-Saturday', '01:47 pm', 1, 0, '', '', ''),
#  ('2019-January-Saturday', '01:47 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-January-Monday', '08:00 am', 1, 0, 'Male', 35, 'Full'),
#  ('2019-January-Monday', '08:00 am', 2, 0, 'Male', 61, 'Full'),
#  ('2019-January-Monday', '06:05 pm', 1, 0, 'Male', 36, 'Full'),
#  ('2019-January-Monday', '06:05 pm', 2, 0, 'Male', 41, 'Full'),
#  ('2019-January-Monday', '06:05 pm', 3, 1, 'Female', 43, 'Full'),
#  ('2019-January-Monday', '06:05 pm', 4, 0, 'Female', 49, 'Full'),
#  ('2019-January-Monday', '04:10 pm', 1, 0, 'Female', 54, 'Full'),
#  ('2019-January-Monday', '04:10 pm', 2, 0, 'Male', 41, ''),
#  ('2019-January-Monday', '02:16 pm', 1, 0, 'Male', 64, ''),
#  ('2019-January-Monday', '02:16 pm', 2, 0, 'Male', 62, 'Full'),
#  ('2019-January-Friday', '12:10 am', 1, 0, 'Male', 36, 'Full'),
#  ('2019-January-Friday', '12:10 am', 2, 0, 'Male', 33, 'Full'),
#  ('2019-January-Friday', '11:00 am', 1, 0, 'Female', 25, 'Full'),
#  ('2019-January-Friday', '11:00 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-January-Friday', '09:05 pm', 1, 1, 'Male', 81, 'Full'),
#  ('2019-January-Friday', '09:05 pm', 2, 0, '', '', ''),
#  ('2019-January-Friday', '06:15 pm', 1, 0, 'Female', 30, 'Full'),
#  ('2019-January-Friday', '06:15 pm', 2, 0, 'Male', 37, 'Full'),
#  ('2019-January-Friday', '05:45 pm', 1, 0, 'Male', 33, 'Full'),
#  ('2019-January-Friday', '05:45 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-January-Friday', '01:00 pm', 1, 0, 'Female', 21, 'Full'),
#  ('2019-January-Friday', '01:00 pm', 2, 1, 'Female', 38, ''),
#  ('2019-February-Wednesday', '08:30 pm', 1, 1, 'Male', 46, ''),
#  ('2019-February-Wednesday', '06:50 am', 1, 1, 'Male', 31, ''),
#  ('2019-February-Wednesday', '06:50 am', 2, 0, 'Male', 45, 'Full'),
#  ('2019-February-Wednesday', '06:40 pm', 1, 0, 'Male', 51, 'Full'),
#  ('2019-February-Wednesday', '06:40 pm', 2, 0, '', '', ''),
# ...
#  ('2019-February-Thursday', '09:50 am', 1, 0, 'Female', 30, 'Full'),
#  ('2019-February-Thursday', '09:50 am', 2, 0, 'Male', 50, 'Full'),
#  ('2019-February-Thursday', '09:50 am', 3, 0, 'Female', 65, 'Full'),
#  ('2019-February-Thursday', '09:50 am', 4, 0, 'Male', 42, 'Full'),
#  ('2019-February-Thursday', '08:34 am', 1, 0, 'Male', 50, 'Full'),
#  ('2019-February-Thursday', '08:34 am', 2, 1, 'Female', 39, ''),
#  ('2019-February-Thursday', '08:34 am', 3, 0, 'Male', 51, 'Full'),
#  ('2019-February-Thursday', '07:40 pm', 1, 0, 'Male', 19, 'Provisional 2'),
#  ('2019-February-Thursday', '07:40 pm', 2, 0, 'Female', 22, 'Full'),
#  ('2019-February-Thursday', '06:45 pm', 1, 1, 'Female', 39, ''),
#  ('2019-February-Thursday', '05:30 pm', 1, 0, 'Male', 33, 'Full'),
#  ('2019-February-Thursday', '05:30 pm', 2, 0, 'Male', 26, 'Full'),
#  ('2019-February-Thursday', '05:05 pm', 1, 0, 'Female', 51, 'Full'),
#  ('2019-February-Thursday', '05:05 pm', 2, 0, 'Female', 47, 'Full'),
#  ('2019-February-Thursday', '04:10 pm', 1, 0, 'Male', 46, 'Full'),
#  ('2019-February-Thursday', '04:10 pm', 2, 1, 'Female', 51, ''),
#  ('2019-February-Thursday', '01:45 pm', 1, 0, 'Male', 31, 'Full'),
#  ('2019-February-Thursday', '01:45 pm', 2, 0, 'Male', 57, 'Full'),
#  ('2019-February-Thursday', '01:30 pm', 1, 0, 'Female', 49, 'Full'),
#  ('2019-February-Thursday', '01:30 pm', 2, 1, 'Male', 21, ''),
#  ('2019-February-Sunday', '10:15 am', 1, 0, 'Male', 70, 'Full'),
#  ('2019-February-Sunday', '10:15 am', 2, 0, 'Male', 60, 'Full'),
#  ('2019-February-Sunday', '07:39 pm', 1, 1, 'Female', 26, 'Full'),
#  ('2019-February-Sunday', '07:39 pm', 2, 0, 'Male', 23, 'Full'),
#  ('2019-February-Sunday', '07:35 am', 1, 0, 'Male', 21, 'Full'),
#  ('2019-February-Sunday', '07:35 am', 2, 0, 'Male', 32, 'Full'),
#  ('2019-February-Sunday', '01:15 pm', 1, 0, 'Male', 29, 'Full'),
#  ('2019-February-Sunday', '01:15 pm', 2, 0, 'Unknown', 'XXX', 'Full'),
#  ('2019-February-Sunday', '01:00 am', 1, 0, 'Male', 36, 'Full'),
#  ('2019-February-Sunday', '01:00 am', 2, 0, 'Male', 20, 'Provisional 2'),
#  ('2019-February-Saturday', '10:30 am', 1, 0, 'Male', 27, 'Full'),
#  ('2019-February-Saturday', '10:30 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-February-Saturday', '07:15 pm', 1, 0, 'Male', 54, 'Full'),
#  ('2019-February-Saturday', '07:15 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-February-Saturday', '03:00 pm', 1, 0, 'Male', 36, 'Full'),
#  ('2019-February-Saturday', '03:00 pm', 2, 1, 'Female', 61, ''),
#  ('2019-February-Saturday', '02:40 pm', 1, 1, 'Male', 61, ''),
#  ('2019-February-Saturday', '02:40 pm', 2, 0, 'Male', 23, 'Provisional 1 '),
#  ('2019-February-Monday', '12:35 pm', 1, 0, 'Male', 49, 'Full'),
#  ('2019-February-Monday', '12:35 pm', 2, 0, 'Female', 51, 'Full'),
#  ('2019-February-Monday', '07:10 pm', 1, 0, 'Male', 20, 'Provisional 2'),
#  ('2019-February-Monday', '07:10 pm', 2, 0, 'Male', 64, 'Full'),
#  ('2019-February-Monday', '05:30 pm', 1, 0, 'Female', 30, 'Provisional 1 '),
#  ('2019-February-Monday', '05:30 pm', 2, 0, 'Female', 50, 'Full'),
#  ('2019-February-Monday', '03:33 pm', 1, 0, 'Male', 37, 'Full'),
#  ('2019-February-Monday', '03:33 pm', 2, 1, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-February-Monday', '01:09 pm', 1, 0, 'Male', 77, 'Full'),
#  ('2019-February-Monday', '01:09 pm', 2, 1, 'Male', 30, 'Full'),
#  ('2019-February-Friday', '12:30 pm', 1, 0, 'Male', 37, 'Full'),
#  ('2019-February-Friday', '12:30 pm', 2, 0, 'Male', 61, 'Full'),
#  ('2019-February-Friday', '11:20 am', 1, 0, 'Male', 39, 'Full'),
#  ('2019-February-Friday', '11:20 am', 2, 0, 'Male', 46, 'Full'),
#  ('2019-February-Friday', '10:10 pm', 1, 0, 'Male', 32, 'Full'),
#  ('2019-February-Friday', '10:10 pm', 2, 0, 'Female', 20, 'Provisional 2'),
#  ('2019-February-Friday', '09:40 am', 1, 0, 'Male', 81, 'Full'),
#  ('2019-February-Friday', '09:40 am', 2, 0, 'Male', 25, 'Full'),
#  ('2019-February-Friday', '09:00 am', 1, 0, 'Female', 34, 'Full'),
#  ('2019-February-Friday', '09:00 am', 2, 1, 'Female', 28, ''),
#  ('2019-February-Friday', '07:55 am', 1, 0, 'Female', 43, 'Full'),
#  ('2019-February-Friday', '07:55 am', 2, 0, 'Female', 21, 'Provisional 2'),
#  ('2019-February-Friday', '06:39 pm', 1, 1, 'Male', 22, 'Full'),
#  ('2019-February-Friday', '06:39 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-February-Friday', '05:45 pm', 1, 0, 'Female', 18, 'Provisional 1 '),
#  ('2019-February-Friday', '05:45 pm', 2, 0, 'Female', 41, 'Full'),
#  ('2019-February-Friday', '05:28 pm', 1, 0, 'Female', 50, 'Full'),
#  ('2019-February-Friday', '05:28 pm', 2, 1, 'Female', 33, 'Full'),
#  ('2019-February-Friday', '04:40 pm', 1, 0, 'Male', 44, 'Full'),
#  ('2019-February-Friday', '04:40 pm', 2, 0, 'Male', 48, ''),
#  ('2019-December-Wednesday', '12:30 pm', 1, 0, 'Male', 73, 'Full'),
#  ('2019-December-Wednesday', '12:30 pm', 2, 0, 'Male', 36, 'Full'),
#  ('2019-December-Wednesday', '11:45 am', 1, 0, 'Male', 65, 'Full'),
#  ('2019-December-Wednesday', '11:45 am', 2, 1, 'Male', 2, ''),
#  ('2019-December-Wednesday', '11:45 am', 1, 0, 'Male', 24, 'Full'),
#  ('2019-December-Wednesday', '11:45 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-December-Wednesday', '05:48 pm', 1, 0, 'Female', 31, 'Full'),
#  ('2019-December-Wednesday', '05:48 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-December-Wednesday', '05:48 pm', 3, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-December-Wednesday', '04:10 pm', 1, 0, 'Male', 61, 'Full'),
#  ('2019-December-Wednesday', '04:10 pm', 2, 0, 'Male', 26, ''),
#  ('2019-December-Wednesday', '02:25 pm', 1, 0, 'Male', 57, 'Full'),
#  ('2019-December-Wednesday', '02:25 pm', 2, 0, 'Male', 25, 'Full'),
#  ('2019-December-Tuesday', '12:30 pm', 1, 0, 'Male', 68, 'Full'),
#  ('2019-December-Tuesday', '12:30 pm', 2, 1, 'Unknown', 'XXX', ''),
#  ('2019-December-Tuesday', '11:00 pm', 1, 0, 'Male', 72, 'Full'),
#  ('2019-December-Tuesday', '11:00 pm', 2, 0, 'Female', 20, 'Unlicenced'),
#  ('2019-December-Tuesday', '09:15 am', 1, 0, 'Male', 49, 'Full'),
#  ('2019-December-Tuesday', '09:15 am', 2, 0, 'Male', 51, 'Full'),
#  ('2019-December-Tuesday', '08:10 am', 1, 0, 'Male', 40, 'Full'),
#  ('2019-December-Tuesday', '08:10 am', 2, 1, 'Male', 55, ''),
#  ('2019-December-Tuesday', '04:35 pm', 1, 0, 'Male', 72, 'Full'),
#  ('2019-December-Tuesday', '04:35 pm', 2, 0, 'Male', 59, ''),
#  ('2019-December-Tuesday', '03:40 pm', 1, 0, 'Male', 65, 'Full'),
#  ('2019-December-Tuesday', '03:40 pm', 2, 0, 'Female', 56, 'Full'),
#  ('2019-December-Tuesday', '03:00 pm', 1, 0, 'Male', 26, 'Full'),
#  ('2019-December-Tuesday', '03:00 pm', 2, 0, 'Female', 34, 'Full'),
#  ('2019-December-Thursday', '09:10 am', 1, 0, 'Female', 28, 'Full'),
#  ('2019-December-Thursday', '09:10 am', 2, 1, 'Male', 71, ''),
#  ('2019-December-Thursday', '08:30 am', 1, 0, 'Male', 52, ''),
#  ('2019-December-Thursday', '08:30 am', 2, 0, 'Male', 39, 'Full'),
#  ('2019-December-Thursday', '07:30 am', 1, 0, 'Male', 34, 'Full'),
#  ('2019-December-Thursday', '07:30 am', 2, 1, 'Female', 65, ''),
#  ('2019-December-Thursday', '06:07 pm', 1, 0, 'Male', 33, 'Full'),
#  ('2019-December-Thursday', '06:07 pm', 2, 1, 'Male', 40, 'Full'),
#  ('2019-December-Thursday', '04:50 pm', 1, 0, 'Male', 31, 'Full'),
#  ('2019-December-Thursday', '04:50 pm', 2, 0, 'Male', 54, 'Full'),
#  ('2019-December-Thursday', '04:25 pm', 1, 0, 'Male', 25, 'Full'),
#  ('2019-December-Thursday', '04:25 pm', 2, 0, 'Male', 64, 'Full'),
#  ('2019-December-Thursday', '02:48 pm', 1, 1, 'Female', 24, 'Full'),
#  ('2019-December-Thursday', '02:48 pm', 2, 0, 'Male', 60, 'Full'),
#  ('2019-December-Sunday', '09:19 am', 1, 0, 'Male', 41, 'Full'),
#  ('2019-December-Sunday', '09:19 am', 2, 0, 'Male', 57, 'Full'),
#  ('2019-December-Sunday', '03:45 pm', 1, 0, 'Female', 83, 'Full'),
#  ('2019-December-Sunday', '03:45 pm', 2, 0, 'Male', 62, 'Full'),
#  ('2019-December-Sunday', '02:00 pm', 1, 0, 'Male', 30, 'Full'),
#  ('2019-December-Sunday', '02:00 pm', 2, 1, 'Male', 59, 'Full'),
#  ('2019-December-Saturday', '10:00 pm', 1, 0, 'Male', 19, 'Unknown'),
#  ('2019-December-Saturday', '10:00 pm', 2, 0, 'Male', 46, ''),
#  ('2019-December-Saturday', '09:55 pm', 1, 0, 'Male', 31, 'Full'),
#  ('2019-December-Saturday', '09:55 pm', 2, 0, 'Male', 50, 'Full'),
#  ('2019-December-Monday', '12:20 pm', 1, 0, 'Female', 32, 'Full'),
#  ('2019-December-Monday', '12:20 pm', 2, 0, 'Male', 63, 'Full'),
#  ('2019-December-Monday', '10:52 am', 1, 2, 'Female', 26, 'Full'),
#  ('2019-December-Monday', '10:52 am', 2, 1, 'Male', 31, 'Full'),
#  ('2019-December-Monday', '09:38 am', 1, 0, 'Female', 51, 'Full'),
#  ('2019-December-Monday', '09:38 am', 2, 0, 'Female', 52, 'Full'),
#  ('2019-December-Monday', '08:48 am', 1, 0, 'Male', 67, 'Full'),
#  ('2019-December-Monday', '08:48 am', 2, 0, 'Male', 50, 'Full'),
#  ('2019-December-Friday', '12:40 pm', 1, 0, 'Female', 37, 'Full'),
#  ('2019-December-Friday', '12:40 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-December-Friday', '11:50 pm', 1, 0, 'Male', 26, ''),
#  ('2019-December-Friday', '11:50 pm', 2, 0, 'Male', 29, 'Full'),
#  ('2019-December-Friday', '08:41 pm', 1, 0, 'Male', 40, 'Full'),
#  ('2019-December-Friday', '08:41 pm', 2, 1, 'Male', 44, ''),
#  ('2019-December-Friday', '06:09 pm', 1, 0, '', '', ''),
#  ('2019-December-Friday', '06:09 pm', 2, 0, 'Male', 55, 'Full'),
#  ('2019-December-Friday', '06:00 pm', 1, 1, 'Male', 29, 'Full'),
#  ('2019-December-Friday', '06:00 pm', 2, 0, 'Male', 26, 'Full'),
#  ('2019-December-Friday', '05:15 pm', 1, 1, 'Female', 32, ''),
#  ('2019-December-Friday', '05:15 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-December-Friday', '04:10 pm', 1, 0, 'Male', 61, 'Full'),
#  ('2019-December-Friday', '04:10 pm', 2, 0, 'Male', 32, 'Full'),
#  ('2019-December-Friday', '03:30 pm', 1, 0, '', '', ''),
#  ('2019-December-Friday', '03:30 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-December-Friday', '01:55 pm', 1, 1, 'Female', 62, 'Full'),
#  ('2019-December-Friday', '01:55 pm', 2, 1, 'Female', 56, 'Full'),
#  ('2019-August-Wednesday', '11:25 am', 1, 0, 'Male', 48, 'Full'),
#  ('2019-August-Wednesday', '11:25 am', 2, 0, 'Female', 36, 'Unlicenced'),
#  ('2019-August-Wednesday', '09:30 pm', 1, 1, 'Male', 72, ''),
#  ('2019-August-Wednesday', '09:30 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-August-Wednesday', '08:00 am', 1, 0, 'Male', 34, 'Full'),
#  ('2019-August-Wednesday', '08:00 am', 2, 1, 'Female', 18, ''),
#  ('2019-August-Wednesday', '08:00 am', 1, 0, 'Male', 56, 'Full'),
#  ('2019-August-Wednesday', '08:00 am', 2, 0, 'Male', 82, 'Full'),
#  ('2019-August-Wednesday', '06:30 pm', 1, 0, 'Female', 53, ''),
#  ('2019-August-Wednesday', '06:30 pm', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-August-Wednesday', '06:10 pm', 1, 0, 'Female', 43, 'Full'),
#  ('2019-August-Wednesday', '06:10 pm', 2, 1, 'Female', 40, ''),
#  ('2019-August-Wednesday', '05:30 pm', 1, 0, 'Female', 36, 'Full'),
#  ('2019-August-Wednesday', '05:30 pm', 2, 0, 'Male', 67, 'Full'),
#  ('2019-August-Wednesday', '04:10 pm', 1, 0, 'Male', 21, ''),
#  ('2019-August-Wednesday', '04:10 pm', 2, 0, 'Male', 26, 'Full'),
#  ('2019-August-Wednesday', '04:00 pm', 1, 0, 'Male', 27, 'Full'),
#  ('2019-August-Wednesday', '04:00 pm', 2, 0, 'Male', 36, 'Full'),
#  ('2019-August-Wednesday', '03:45 pm', 1, 0, 'Male', 19, 'Provisional 2'),
#  ('2019-August-Wednesday', '03:45 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-August-Tuesday', '12:50 pm', 1, 0, 'Male', 68, 'Full'),
#  ('2019-August-Tuesday', '12:50 pm', 2, 0, 'Female', 21, ''),
#  ('2019-August-Tuesday', '09:55 am', 1, 0, '', '', ''),
#  ('2019-August-Tuesday', '09:55 am', 2, 0, 'Male', 46, 'Full'),
#  ('2019-August-Tuesday', '09:55 am', 3, 0, '', '', ''),
#  ('2019-August-Tuesday', '09:45 am', 1, 0, 'Male', 19, 'Provisional 2'),
#  ('2019-August-Tuesday', '09:45 am', 2, 0, 'Male', 27, 'Full'),
#  ('2019-August-Tuesday', '09:00 am', 1, 1, 'Male', 42, ''),
#  ('2019-August-Tuesday', '09:00 am', 2, 0, 'Female', 'XXX', 'Full'),
#  ('2019-August-Tuesday', '08:40 am', 1, 0, 'Female', 63, 'Full'),
#  ('2019-August-Tuesday', '08:40 am', 2, 0, 'Male', 59, 'Full'),
#  ('2019-August-Tuesday', '08:10 pm', 1, 0, 'Male', 64, 'Full'),
#  ('2019-August-Tuesday', '08:10 pm', 2, 1, 'Male', 33, ''),
#  ('2019-August-Tuesday', '06:00 pm', 1, 0, '', '', ''),
#  ('2019-August-Tuesday', '06:00 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-August-Tuesday', '05:45 pm', 1, 0, 'Male', 36, 'Full'),
#  ('2019-August-Tuesday', '05:45 pm', 2, 0, 'Male', 39, 'Full'),
#  ('2019-August-Tuesday', '05:30 pm', 1, 0, 'Male', 26, ''),
#  ('2019-August-Tuesday', '05:30 pm', 2, 0, 'Male', 70, 'Full'),
#  ('2019-August-Tuesday', '05:00 pm', 1, 0, 'Male', 35, 'Full'),
#  ('2019-August-Tuesday', '05:00 pm', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-August-Tuesday', '02:00 pm', 1, 0, 'Male', 44, 'Full'),
#  ('2019-August-Tuesday', '02:00 pm', 2, 0, 'Female', 84, 'Full'),
#  ('2019-August-Tuesday', '01:30 pm', 1, 0, 'Male', 54, 'Full'),
#  ('2019-August-Tuesday', '01:30 pm', 2, 0, 'Male', 56, 'Full'),
#  ('2019-August-Thursday', '12:00 pm', 1, 0, 'Male', 30, 'Full'),
#  ('2019-August-Thursday', '12:00 pm', 2, 1, 'Female', 42, ''),
#  ('2019-August-Thursday', '11:30 am', 1, 1, 'Male', 35, 'Full'),
#  ('2019-August-Thursday', '10:46 pm', 1, 0, 'Male', 22, 'Full'),
#  ('2019-August-Thursday', '10:46 pm', 2, 1, 'Male', 37, ''),
#  ('2019-August-Thursday', '10:00 am', 1, 1, 'Female', 62, ''),
#  ('2019-August-Thursday', '08:30 pm', 1, 1, 'Female', 45, ''),
#  ('2019-August-Thursday', '08:30 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-August-Thursday', '08:30 am', 1, 0, 'Female', 59, 'Full'),
#  ('2019-August-Thursday', '08:30 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-August-Thursday', '08:20 am', 1, 0, 'Male', 39, 'Full'),
#  ('2019-August-Thursday', '08:20 am', 2, 0, 'Male', 24, 'Full'),
#  ('2019-August-Thursday', '08:20 am', 1, 0, 'Female', 44, 'Full'),
#  ('2019-August-Thursday', '08:20 am', 2, 0, 'Unknown', 'XXX', ''),
#  ('2019-August-Thursday', '06:15 am', 1, 0, 'Female', 27, 'Unknown'),
#  ('2019-August-Thursday', '06:15 am', 2, 0, 'Male', 55, 'Unknown'),
#  ('2019-August-Thursday', '05:10 pm', 1, 1, 'Female', 38, ''),
#  ('2019-August-Thursday', '05:10 pm', 2, 0, 'Male', 25, 'Unlicenced'),
#  ('2019-August-Sunday', '12:41 pm', 1, 0, 'Male', 36, 'Full'),
#  ('2019-August-Sunday', '12:41 pm', 2, 0, 'Female', 45, 'Full'),
#  ('2019-August-Sunday', '08:30 am', 1, 0, 'Male', 39, 'Full'),
#  ('2019-August-Sunday', '08:30 am', 2, 0, 'Male', 33, 'Full'),
#  ('2019-August-Sunday', '07:05 pm', 1, 0, 'Male', 47, 'Full'),
#  ('2019-August-Sunday', '07:05 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-August-Sunday', '02:35 am', 1, 0, 'Female', 20, 'Provisional 2'),
#  ('2019-August-Sunday', '02:35 am', 2, 0, 'Male', 28, 'Full'),
#  ('2019-August-Saturday', '12:45 pm', 1, 1, 'Female', 25, 'Full'),
#  ('2019-August-Saturday', '12:45 pm', 2, 0, 'Male', 35, 'Full'),
#  ('2019-August-Saturday', '12:45 pm', 3, 0, 'Female', 41, 'Full'),
#  ('2019-August-Saturday', '11:39 am', 1, 0, 'Female', 22, 'Provisional 1 '),
#  ('2019-August-Saturday', '11:39 am', 2, 0, 'Male', 66, 'Full'),
#  ('2019-August-Saturday', '10:50 am', 1, 0, 'Male', 55, 'Full'),
#  ('2019-August-Saturday', '10:50 am', 2, 0, 'Male', 69, 'Full'),
#  ('2019-August-Saturday', '08:21 am', 1, 0, 'Female', 17, 'Provisional 1 '),
#  ('2019-August-Saturday', '08:21 am', 2, 0, 'Female', 33, 'Full'),
#  ('2019-August-Saturday', '08:00 pm', 1, 0, 'Male', 32, 'Full'),
#  ('2019-August-Saturday', '08:00 pm', 2, 0, 'Female', 30, 'Full'),
#  ('2019-August-Saturday', '05:40 pm', 1, 0, 'Male', 19, 'Full'),
#  ('2019-August-Saturday', '05:40 pm', 2, 0, 'Female', 22, 'Provisional 2'),
#  ('2019-August-Saturday', '02:30 pm', 1, 0, 'Female', 42, 'Full'),
#  ('2019-August-Saturday', '02:30 pm', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-August-Monday', '12:30 pm', 1, 0, 'Female', 89, 'Full'),
#  ('2019-August-Monday', '12:30 pm', 2, 1, 'Female', 57, ''),
#  ('2019-August-Monday', '10:50 am', 1, 0, '', '', ''),
#  ('2019-August-Monday', '10:50 am', 2, 0, 'Unknown', 'XXX', 'Unknown'),
#  ('2019-August-Monday', '09:10 am', 1, 0, 'Male', 31, 'Full'),
#  ('2019-August-Monday', '09:10 am', 2, 0, 'Male', 64, 'Full'),
#  ('2019-August-Monday', '08:45 am', 1, 1, 'Female', 44, 'Full'),
#  ('2019-August-Monday', '08:45 am', 2, 0, 'Female', 23, 'Provisional 2'),
#  ...]

# %% [markdown]
# ### DataFrame

# %%
# %%time
# Log the time taken for the query

# Filter the crash DF for the Adelaide suburb only 
df_crash_adelaide = df_crash.filter(f.col('Suburb') == 'ADELAIDE')
# Join the 2 DFs on REPORT_ID
df_joined = df_units.join(df_crash_adelaide,
                          df_units.REPORT_ID == df_crash_adelaide.REPORT_ID,
                          how = 'inner')

# Concatenate the date as required and select all the other required columns
df_joined = df_joined.select(f.concat(f.col('Year'), f.lit('-'), f.col('Month'), f.lit('-'), f.col('Day')),
                             f.col('Time'), f.col('Unit No'), f.col('No of Cas'),
                             f.col('Sex'), f.col('Age'), f.col('Licence Type'))\
                            .withColumnRenamed('concat(Year, -, Month, -, Day)', 'Date')\
                            .sort('Date', 'Time', ascending = False) # Sort by date and time for easy comparison

# Print the total number of rows in the result
print('Total rows: ', df_joined.count())
# Show the result DF
df_joined.show(truncate = False)
# Out:
# Total rows:  6310
# +------------------------+--------+-------+---------+-------+---+------------+
# |Date                    |Time    |Unit No|No of Cas|Sex    |Age|Licence Type|
# +------------------------+--------+-------+---------+-------+---+------------+
# |2019-September-Wednesday|11:40 am|1      |0        |Male   |056|Full        |
# |2019-September-Wednesday|11:40 am|2      |0        |Unknown|XXX|Unknown     |
# |2019-September-Wednesday|11:38 am|1      |0        |Male   |029|Full        |
# |2019-September-Wednesday|11:38 am|2      |1        |Male   |073|null        |
# |2019-September-Wednesday|07:55 pm|2      |0        |Unknown|XXX|null        |
# |2019-September-Wednesday|07:55 pm|1      |1        |Female |031|null        |
# |2019-September-Wednesday|06:50 pm|2      |0        |Male   |039|Full        |
# |2019-September-Wednesday|06:50 pm|1      |0        |Female |075|Full        |
# |2019-September-Wednesday|06:00 pm|1      |1        |Female |038|null        |
# |2019-September-Wednesday|06:00 pm|2      |0        |Unknown|XXX|null        |
# |2019-September-Wednesday|04:36 pm|1      |1        |Male   |028|null        |
# |2019-September-Wednesday|04:36 pm|2      |1        |Female |033|null        |
# |2019-September-Wednesday|04:10 pm|2      |0        |Male   |050|Full        |
# |2019-September-Wednesday|04:10 pm|1      |0        |Female |029|Full        |
# |2019-September-Wednesday|03:30 pm|1      |0        |Male   |074|Full        |
# |2019-September-Wednesday|03:30 pm|2      |0        |Unknown|XXX|null        |
# |2019-September-Wednesday|03:05 pm|1      |0        |Male   |045|Full        |
# |2019-September-Wednesday|03:05 pm|2      |0        |Male   |XXX|null        |
# |2019-September-Wednesday|02:20 pm|2      |1        |Male   |040|null        |
# |2019-September-Wednesday|02:20 pm|1      |0        |Female |023|Unknown     |
# +------------------------+--------+-------+---------+-------+---+------------+
# only showing top 20 rows
#
# CPU times: user 11 ms, sys: 91 µs, total: 11.1 ms
# Wall time: 1.98 s

# %% [markdown]
# ### Spark SQL

# %%
# %%time
# Log the time taken for the query

# Write the SQL query for retreiving the required result and store it
sql_query = spark.sql('''
  SELECT
      CONCAT(c.Year, '-', c.Month, '-', c.Day) AS Date,
      c.Time,
      u.`Unit No`,
      u.`No of Cas`,
      u.Sex,
      u.Age,
      u.`Licence Type`
  FROM sql_units u
  JOIN sql_crash c ON u.REPORT_ID = c.REPORT_ID
  WHERE c.Suburb = 'ADELAIDE'
  ORDER BY CONCAT(c.Year, '-', c.Month, '-', c.Day) DESC, c.Time DESC
''')

# Print the total number of rows in the result
print('Total rows: ', sql_query.count())
# Show the result of the SQL query
sql_query.show(truncate = False)
# Out:
# Total rows:  6310
# +------------------------+--------+-------+---------+-------+---+------------+
# |Date                    |Time    |Unit No|No of Cas|Sex    |Age|Licence Type|
# +------------------------+--------+-------+---------+-------+---+------------+
# |2019-September-Wednesday|11:40 am|1      |0        |Male   |056|Full        |
# |2019-September-Wednesday|11:40 am|2      |0        |Unknown|XXX|Unknown     |
# |2019-September-Wednesday|11:38 am|1      |0        |Male   |029|Full        |
# |2019-September-Wednesday|11:38 am|2      |1        |Male   |073|null        |
# |2019-September-Wednesday|07:55 pm|2      |0        |Unknown|XXX|null        |
# |2019-September-Wednesday|07:55 pm|1      |1        |Female |031|null        |
# |2019-September-Wednesday|06:50 pm|2      |0        |Male   |039|Full        |
# |2019-September-Wednesday|06:50 pm|1      |0        |Female |075|Full        |
# |2019-September-Wednesday|06:00 pm|1      |1        |Female |038|null        |
# |2019-September-Wednesday|06:00 pm|2      |0        |Unknown|XXX|null        |
# |2019-September-Wednesday|04:36 pm|1      |1        |Male   |028|null        |
# |2019-September-Wednesday|04:36 pm|2      |1        |Female |033|null        |
# |2019-September-Wednesday|04:10 pm|2      |0        |Male   |050|Full        |
# |2019-September-Wednesday|04:10 pm|1      |0        |Female |029|Full        |
# |2019-September-Wednesday|03:30 pm|1      |0        |Male   |074|Full        |
# |2019-September-Wednesday|03:30 pm|2      |0        |Unknown|XXX|null        |
# |2019-September-Wednesday|03:05 pm|1      |0        |Male   |045|Full        |
# |2019-September-Wednesday|03:05 pm|2      |0        |Male   |XXX|null        |
# |2019-September-Wednesday|02:20 pm|2      |1        |Male   |040|null        |
# |2019-September-Wednesday|02:20 pm|1      |0        |Female |023|Unknown     |
# +------------------------+--------+-------+---------+-------+---+------------+
# only showing top 20 rows
#
# CPU times: user 0 ns, sys: 3.41 ms, total: 3.41 ms
# Wall time: 1.89 s

# %% [markdown]
#  <div class="alert alert-block alert-info">
# 2. Find the total number of casualties for each suburb when the vehicle was driven by an
# unlicensed driver. You are required to display the name of the suburb and the total
# number of casualties.

# %% [markdown]
# ### RDD

# %%
# %%time
# Log the time taken for the query

# Create a Key Value pair with REPORT_ID as the key and the required columns as values for both the RDDs
rdd_units_kv = rdd_units.map(lambda x: (x[0], (x[1], x[11])))
rdd_crash_kv = rdd_crash.map(lambda x: (x[0], (x[2], int(x[6]))))

# Filter the units RDD only for the unlicenced drivers
rdd_units_kv = rdd_units_kv.filter(lambda x: x[1][1] == 'Unlicenced')

# Join the 2 RDDs on REPORT_ID
rdd_joined = rdd_units_kv.join(rdd_crash_kv)

# Select the elements as required and store them
rdd_joined = rdd_joined.map(lambda x: (x[1][1][0], (x[1][1][1], x[1][0][1])))
rdd_joined = rdd_joined.map(lambda x: (x[0], x[1][0]))
# Group by suburb, aggregate the sum of casualties accordingly and sort them based on the total sum for easy comparison
rdd_joined = rdd_joined.groupByKey().mapValues(sum).sortBy(lambda x: (x[1], x[0]), ascending = False)

# Print the total number of rows in the result
print('Total rows: ', rdd_joined.count())
# Show the result RDD
rdd_joined.collect()
# Out:
# Total rows:  634
# CPU times: user 67.1 ms, sys: 10.7 ms, total: 77.8 ms
# Wall time: 3.5 s
# [('ADELAIDE', 19),
#  ('SALISBURY', 18),
#  ('DRY CREEK', 18),
#  ('SALISBURY EAST', 16),
#  ('PROSPECT', 14),
#  ('NORTH ADELAIDE', 13),
#  ('ENFIELD', 12),
#  ('ANDREWS FARM', 12),
#  ('SALISBURY SOUTH', 11),
#  ('SALISBURY DOWNS', 11),
#  ('INGLE FARM', 11),
#  ('BEDFORD PARK', 11),
#  ('SALISBURY PLAIN', 10),
#  ('MUNNO PARA', 10),
#  ('MOUNT BARKER', 10),
#  ('MORPHETT VALE', 10),
#  ('MAWSON LAKES', 10),
#  ('ELIZABETH PARK', 10),
#  ('BURTON', 10),
#  ('SALISBURY NORTH', 9),
#  ('PLYMPTON', 9),
#  ('PARA HILLS WEST', 9),
#  ('HOLDEN HILL', 9),
#  ('ELIZABETH GROVE', 9),
#  ('ELIZABETH EAST', 9),
#  ('SOUTH PLYMPTON', 8),
#  ('SEATON', 8),
#  ('MOUNT GAMBIER', 8),
#  ('FLINDERS PARK', 8),
#  ('ELIZABETH SOUTH', 8),
#  ('DAVOREN PARK', 8),
#  ('WHYALLA NORRIE', 7),
#  ('PARAFIELD GARDENS', 7),
#  ('ONKAPARINGA HILLS', 7),
#  ('MURRAY BRIDGE', 7),
#  ('MAGILL', 7),
#  ('KANGARILLA', 7),
#  ('GILLES PLAINS', 7),
#  ('COOBER PEDY', 7),
#  ('BURRA', 7),
#  ('BROOKLYN PARK', 7),
#  ('WYNN VALE', 6),
#  ('WINGFIELD', 6),
#  ('WATERLOO CORNER', 6),
#  ('WARRADALE', 6),
#  ('VALLEY VIEW', 6),
#  ('TRANMERE', 6),
#  ('STURT', 6),
#  ('ST MARYS', 6),
#  ('SMITHFIELD', 6),
#  ('ROSEWORTHY', 6),
#  ('PENFIELD', 6),
#  ('MILE END', 6),
#  ('KLEMZIG', 6),
#  ('HACKHAM WEST', 6),
#  ('FINDON', 6),
#  ('ELIZABETH NORTH', 6),
#  ('ELIZABETH DOWNS', 6),
#  ('EDWARDSTOWN', 6),
#  ('CHAIN OF PONDS', 6),
#  ('TORRENSVILLE', 5),
#  ('STEPNEY', 5),
#  ('SEMAPHORE SOUTH', 5),
#  ('PAYNEHAM', 5),
#  ('PARKSIDE', 5),
#  ('MITCHELL PARK', 5),
#  ('MELROSE PARK', 5),
#  ('MEADOWS', 5),
#  ('MCLAREN VALE', 5),
#  ('LONSDALE', 5),
#  ('HAPPY VALLEY', 5),
#  ('EYRE', 5),
#  ('DAWESLEY', 5),
#  ('CURRENCY CREEK', 5),
#  ('CHRISTIE DOWNS', 5),
#  ('BROADVIEW', 5),
#  ('ANGLE VALE', 5),
#  ('WOODVILLE GARDENS', 4),
#  ('WILMINGTON', 4),
#  ('WHYALLA STUART', 4),
#  ('WEST LAKES', 4),
#  ('TOTNESS', 4),
#  ('TORRENS PARK', 4),
#  ('SUMMERTOWN', 4),
#  ('SEDAN', 4),
#  ('SEAFORD MEADOWS', 4),
#  ('PORT NOARLUNGA', 4),
#  ('PORT ADELAIDE', 4),
#  ('PEWSEY VALE', 4),
#  ('PARK HOLME', 4),
#  ('PARALOWIE', 4),
#  ('PARADISE', 4),
#  ('PARA HILLS', 4),
#  ('OAKDEN', 4),
#  ('NORWOOD', 4),
#  ('MYPONGA', 4),
#  ('MARION', 4),
#  ('KENT TOWN', 4),
#  ('GLENELG NORTH', 4),
#  ('GEPPS CROSS', 4),
#  ('FITZROY', 4),
#  ('ELIZABETH VALE', 4),
#  ('DIREK', 4),
#  ('CROYDON', 4),
#  ('CHELTENHAM', 4),
#  ('CALLINGTON', 4),
#  ('BEULAH PARK', 4),
#  ('BAUDIN BEACH', 4),
#  ('BALHANNAH', 4),
#  ('YUNTA', 3),
#  ('YATTALUNGA', 3),
#  ('WOODVILLE WEST', 3),
#  ('WHYALLA PLAYFORD', 3),
#  ('WEST HINDMARSH', 3),
#  ('WALKLEY HEIGHTS', 3),
#  ('VIRGINIA', 3),
#  ('VICTOR HARBOR', 3),
#  ('UNDALYA', 3),
#  ('SUTTONTOWN', 3),
#  ('STIRLING NORTH', 3),
#  ('ST CLAIR', 3),
#  ('SOMERTON PARK', 3),
#  ('SEAFORD RISE', 3),
#  ('RIDLEYTON', 3),
#  ('REGENCY PARK', 3),
#  ('PUKATJA', 3),
#  ('PORT AUGUSTA', 3),
#  ('PIPALYATJARA', 3),
#  ('PENFIELD GARDENS', 3),
#  ('PARACOMBE', 3),
#  ('OSBORNE', 3),
#  ('OAKLANDS PARK', 3),
#  ("O'HALLORAN HILL", 3),
#  ('MORPHETTVILLE', 3),
#  ('MONARTO SOUTH', 3),
#  ('MODBURY NORTH', 3),
#  ('MEDINDIE', 3),
#  ('MARDEN', 3),
#  ('LEAWOOD GARDENS', 3),
#  ('KAPUNDA', 3),
#  ('HUNTFIELD HEIGHTS', 3),
#  ('HOUGHTON', 3),
#  ('HILLIER', 3),
#  ('HARTLEY', 3),
#  ('HALLETT COVE', 3),
#  ('HACKHAM', 3),
#  ('GOLDEN GROVE', 3),
#  ('GLOSSOP', 3),
#  ('GLOBE DERBY PARK', 3),
#  ('GAWLER WEST', 3),
#  ('GAWLER SOUTH', 3),
#  ('FREELING', 3),
#  ('FLAGSTAFF HILL', 3),
#  ('EVANSTON PARK', 3),
#  ('ELIZABETH', 3),
#  ('BORDERTOWN', 3),
#  ('BOLIVAR', 3),
#  ('BLAKEVIEW', 3),
#  ('BLAIR ATHOL', 3),
#  ('BERRI', 3),
#  ('APY', 3),
#  ('ALDINGA', 3),
#  ('YORKETOWN', 2),
#  ('WOODVILLE PARK', 2),
#  ('WOODVILLE NORTH', 2),
#  ('WINDSOR GARDENS', 2),
#  ('WINDSOR', 2),
#  ('WILLIAMSTOWN', 2),
#  ('WEST CROYDON', 2),
#  ('WAYVILLE', 2),
#  ('WALLAROO', 2),
#  ('WALKERVILLE', 2),
#  ('VALE PARK', 2),
#  ('URRBRAE', 2),
#  ('UNLEY', 2),
#  ('TWO WELLS', 2),
#  ('TIATUKIA', 2),
#  ('TAPEROO', 2),
#  ('SWAN REACH', 2),
#  ('ST AGNES', 2),
#  ('SMITHFIELD PLAINS', 2),
#  ('SEMAPHORE PARK', 2),
#  ('SEAFORD', 2),
#  ('ROXBY DOWNS', 2),
#  ('ROCKY CAMP', 2),
#  ('RENOWN PARK', 2),
#  ('REDWOOD PARK', 2),
#  ('PORT PIRIE SOUTH', 2),
#  ('PORT LINCOLN', 2),
#  ('PORT AUGUSTA WEST', 2),
#  ('POORAKA', 2),
#  ('PINNAROO', 2),
#  ('PASADENA', 2),
#  ('PARA VISTA', 2),
#  ('PALMER', 2),
#  ('OVERLAND CORNER', 2),
#  ('ONE TREE HILL', 2),
#  ('OLD NOARLUNGA', 2),
#  ("O'SULLIVAN BEACH", 2),
#  ('NOVAR GARDENS', 2),
#  ('NORTHFIELD', 2),
#  ('NOARLUNGA DOWNS', 2),
#  ('NILDOTTIE', 2),
#  ('NARACOORTE', 2),
#  ('NANGKITA', 2),
#  ('NAIRNE', 2),
#  ('NAILSWORTH', 2),
#  ('MUNNO PARA DOWNS', 2),
#  ('MOUNT BRYAN', 2),
#  ('MODBURY', 2),
#  ('MILLICENT', 2),
#  ('MENINGIE', 2),
#  ('MCHARG CREEK', 2),
#  ('MAYLANDS', 2),
#  ('MASLIN BEACH', 2),
#  ('MARRYATVILLE', 2),
#  ('MANNANARIE', 2),
#  ('LOWER INMAN VALLEY', 2),
#  ('LARGS NORTH', 2),
#  ('LARGS BAY', 2),
#  ('LAMEROO', 2),
#  ('KURRALTA PARK', 2),
#  ('KUDLA', 2),
#  ('KORUNYE', 2),
#  ('KILBURN', 2),
#  ('KIDMAN PARK', 2),
#  ('KENSINGTON PARK', 2),
#  ('KENSINGTON', 2),
#  ('KANGAROO INN', 2),
#  ('IWANTJA', 2),
#  ('INNESTON', 2),
#  ('INKERMAN', 2),
#  ('HINDMARSH VALLEY', 2),
#  ('HINDMARSH', 2),
#  ('HENLEY BEACH SOUTH', 2),
#  ('HAZELWOOD PARK', 2),
#  ('HAINES', 2),
#  ('HAHNDORF', 2),
#  ('HACKNEY', 2),
#  ('GREEN FIELDS', 2),
#  ('GLYNDE', 2),
#  ('GLENSIDE', 2),
#  ('GLENELG EAST', 2),
#  ('GEORGETOWN', 2),
#  ('FULHAM GARDENS', 2),
#  ('FINNISS', 2),
#  ('FERRYDEN PARK', 2),
#  ('FELIXSTOW', 2),
#  ('EDINBURGH', 2),
#  ('DERNANCOURT', 2),
#  ('CUDLEE CREEK', 2),
#  ('CRAIGMORE', 2),
#  ('COMMISSARIAT POINT', 2),
#  ('COLLINSWOOD', 2),
#  ('COLLEGE PARK', 2),
#  ('CLARENCE GARDENS', 2),
#  ('CHRISTIES BEACH', 2),
#  ('CEDUNA', 2),
#  ('CARAWA', 2),
#  ('CAMPBELLTOWN', 2),
#  ('BROMPTON', 2),
#  ('BRIGHTON', 2),
#  ('BRIDGEWATER', 2),
#  ('BRAHMA LODGE', 2),
#  ('BIRKENHEAD', 2),
#  ('ASHVILLE', 2),
#  ('ASCOT PARK', 2),
#  ('ANGASTON', 2),
#  ('ANANGU PITJANTJATJARA YANKUNYTJATARA', 2),
#  ('ALLENBY GARDENS', 2),
#  ('ALDINGA BEACH', 2),
#  ('ALBERTON', 2),
#  ('ALBERT PARK', 2),
#  ('YATALA VALE', 1),
#  ('YAMBA', 1),
#  ('YALATA', 1),
#  ('YAHL', 1),
#  ('WOODVILLE SOUTH', 1),
#  ('WOODVILLE', 1),
#  ('WISANGER', 1),
#  ('WILLUNGA', 1),
#  ('WILLAMULKA', 1),
#  ('WILD HORSE PLAINS', 1),
#  ('WIGLEY FLAT', 1),
#  ('WHYALLA JENKINS', 1),
#  ('WHYALLA', 1),
#  ('WESTBOURNE PARK', 1),
#  ('WESTALL', 1),
#  ('WEST RICHMOND', 1),
#  ('WELLAND', 1),
#  ('WARNERTOWN', 1),
#  ('WARD BELT', 1),
#  ('WALKER FLAT', 1),
#  ('WAIKERIE', 1),
#  ('VERDUN', 1),
#  ('UNDERDALE', 1),
#  ('TROTT PARK', 1),
#  ('TRINITY GARDENS', 1),
#  ('TOTHILL CREEK', 1),
#  ('TOOPERANG', 1),
#  ('TODMORDEN', 1),
#  ('THORNGATE', 1),
#  ('THEBARTON', 1),
#  ('THE PINES', 1),
#  ('TENNYSON', 1),
#  ('TEA TREE GULLY', 1),
#  ('TATACHILLA', 1),
#  ('TANUNDA', 1),
#  ('TAILEM BEND', 1),
#  ('STOCKPORT', 1),
#  ('STIRLING', 1),
#  ('ST PETERS', 1),
#  ('ST GEORGES', 1),
#  ('SOUTHEND', 1),
#  ('SOUTH BRIGHTON', 1),
#  ('SNOWTOWN', 1),
#  ('SHEIDOW PARK', 1),
#  ('SEMAPHORE', 1),
#  ('SELLICKS HILL', 1),
#  ('SAMPSON FLAT', 1),
#  ('SALISBURY HEIGHTS', 1),
#  ('ROYSTON PARK', 1),
#  ('ROYAL PARK', 1),
#  ('ROSTREVOR', 1),
#  ('ROSSLYN PARK', 1),
#  ('ROSEWATER', 1),
#  ('ROCKY GULLY', 1),
#  ('RIVERGLADES', 1),
#  ('RISDON PARK SOUTH', 1),
#  ('RISDON PARK', 1),
#  ('RICHMOND', 1),
#  ('REYNELLA', 1),
#  ('RENMARK SOUTH', 1),
#  ('RENMARK NORTH', 1),
#  ('PURNONG', 1),
#  ('PORTER LAGOON', 1),
#  ('PORT WAKEFIELD', 1),
#  ('PORT RICKABY', 1),
#  ('PORT NOARLUNGA SOUTH', 1),
#  ('PORT MACDONNELL', 1),
#  ('PORT ELLIOT', 1),
#  ('POOGINAGORIC', 1),
#  ('POLTALLOCH', 1),
#  ('POINT STURT', 1),
#  ('PENRICE', 1),
#  ('PENONG', 1),
#  ('PENNINGTON', 1),
#  ('PENNESHAW', 1),
#  ('PARIS CREEK', 1),
#  ('PARAFIELD', 1),
#  ('OVINGHAM', 1),
#  ('OTTOWAY', 1),
#  ('OLYMPIC DAM', 1),
#  ('OLD REYNELLA', 1),
#  ('OAKDEN HILLS', 1),
#  ('NURIOOTPA', 1),
#  ('NORTH PLYMPTON', 1),
#  ('NORMANVILLE', 1),
#  ('NOARLUNGA CENTRE', 1),
#  ('NEWTON', 1),
#  ('NETLEY', 1),
#  ('NEPABUNNA', 1),
#  ('NANGWARRY', 1),
#  ('NALYAPPA', 1),
#  ('MURRAY BRIDGE NORTH', 1),
#  ('MURRAY BRIDGE EAST', 1),
#  ('MUNNO PARA WEST', 1),
#  ('MOUNT MARY', 1),
#  ('MOUNT GEORGE', 1),
#  ('MOUNT CRAWFORD', 1),
#  ('MOUNT COMPASS', 1),
#  ('MODBURY HEIGHTS', 1),
#  ('MINGBOOL', 1),
#  ('MILLBROOK', 1),
#  ('MILE END SOUTH', 1),
#  ('MIDDLEBACK RANGE', 1),
#  ('MCLAREN FLAT', 1),
#  ('MCDOUALL PEAK', 1),
#  ('MARINO', 1),
#  ('MALLALA', 1),
#  ('MAITLAND', 1),
#  ('LOXTON', 1),
#  ('LOWER LIGHT', 1),
#  ('LOUTH BAY', 1),
#  ('LOCKLEYS', 1),
#  ('LOCHABER', 1),
#  ('LITTLEHAMPTON', 1),
#  ('LINWOOD', 1),
#  ('LINDEN PARK', 1),
#  ('LEABROOK', 1),
#  ('LANGHORNE CREEK', 1),
#  ('KULPARA', 1),
#  ('KONGORONG', 1),
#  ('KINGSTON ON MURRAY', 1),
#  ('KESWICK TERMINAL', 1),
#  ('KESWICK', 1),
#  ('KERSBROOK', 1),
#  ('KEPPOCH', 1),
#  ('KADINA', 1),
#  ('JAMESTOWN', 1),
#  ('HOVE', 1),
#  ('HILTON', 1),
#  ('HILLBANK', 1),
#  ('HIGHBURY', 1),
#  ('HENLEY BEACH', 1),
#  ('HAWTHORN', 1),
#  ('HASLAM', 1),
#  ('HAMLEY BRIDGE', 1),
#  ('HALBURY', 1),
#  ('GREENWITH', 1),
#  ('GREENACRES', 1),
#  ('GRANGE', 1),
#  ('GOOLWA BEACH', 1),
#  ('GOOLWA', 1),
#  ('GLENGOWRIE', 1),
#  ('GLENELG SOUTH', 1),
#  ('GLENELG', 1),
#  ('GLEN OSMOND', 1),
#  ('GLANVILLE', 1),
#  ('GLANDORE', 1),
#  ('GAWLER EAST', 1),
#  ('GAWLER', 1),
#  ('FORRESTON', 1),
#  ('FORESTVILLE', 1),
#  ('FITZGERALD BAY', 1),
#  ('FIRLE', 1),
#  ('FIELD', 1),
#  ('EVERARD PARK', 1),
#  ('EVANSTON', 1),
#  ('ETTRICK', 1),
#  ('ETHELTON', 1),
#  ('ERINGA', 1),
#  ('ENCOUNTER BAY', 1),
#  ('EIGHT MILE CREEK', 1),
#  ('EDINBURGH NORTH', 1),
#  ('ECHUNGA', 1),
#  ('DOUGLAS POINT', 1),
#  ('DARLINGTON', 1),
#  ('CYGNET RIVER', 1),
#  ('CUNLIFFE', 1),
#  ('CULTANA', 1),
#  ('CROYDON PARK', 1),
#  ('CRESCENT', 1),
#  ('CRAFERS WEST', 1),
#  ('CRAFERS', 1),
#  ('COWELL', 1),
#  ('COWANDILLA', 1),
#  ('COROMANDEL EAST', 1),
#  ('CONMURRA', 1),
#  ('COFFIN BAY', 1),
#  ('CLOVELLY PARK', 1),
#  ('CLELAND', 1),
#  ('CLAY WELLS', 1),
#  ('CHANDLERS HILL', 1),
#  ('CHAFFEY', 1),
#  ('CAVAN', 1),
#  ('CASSINI', 1),
#  ('CAREY GULLY', 1),
#  ('CAMDEN PARK', 1),
#  ('BUCKLAND PARK', 1),
#  ('BRUKUNGA', 1),
#  ('BOWER', 1),
#  ('BOWDEN', 1),
#  ('BOOKABIE', 1),
#  ('BLYTH', 1),
#  ('BLACKWOOD', 1),
#  ('BINNUM', 1),
#  ('BIBARINGA', 1),
#  ('BEVERLEY', 1),
#  ('BETHANY', 1),
#  ('BELAIR', 1),
#  ('BEAUFORT', 1),
#  ('BEACHPORT', 1),
#  ('AUBURN', 1),
#  ('ATHOL PARK', 1),
#  ('ASHFORD', 1),
#  ('ARMAGH', 1),
#  ('ANNADALE', 1),
#  ('AMATA', 1),
#  ('ALLENDALE EAST', 1),
#  ('ABERFOYLE PARK', 1),
#  ('YANKALILLA', 0),
#  ('WORROLONG', 0),
#  ('WINNINOWIE', 0),
#  ('WILLASTON', 0),
#  ('WHITES FLAT', 0),
#  ('WEST BEACH', 0),
#  ('WATERFALL GULLY', 0),
#  ('WALLAROO MINES', 0),
#  ('VISTA', 0),
#  ('UPPER HERMITAGE', 0),
#  ('UNLEY PARK', 0),
#  ('UMUWA', 0),
#  ('ULEYBURY', 0),
#  ('TUSMORE', 0),
#  ('TUNGKILLO', 0),
#  ('TUMBY BAY', 0),
#  ('TRURO', 0),
#  ('TOORAK GARDENS', 0),
#  ('TINTINARA', 0),
#  ('TELOWIE', 0),
#  ('TANTANOOLA', 0),
#  ('SURREY DOWNS', 0),
#  ('STRUAN', 0),
#  ('STREAKY BAY', 0),
#  ('ST MORRIS', 0),
#  ('SPALDING', 0),
#  ('SOLOMONTOWN', 0),
#  ('SEPPELTSFIELD', 0),
#  ('SELLICKS BEACH', 0),
#  ('SEFTON PARK', 0),
#  ('SEDDON', 0),
#  ('SEACOMBE HEIGHTS', 0),
#  ('SEACLIFF PARK', 0),
#  ('SEACLIFF', 0),
#  ('SALISBURY PARK', 0),
#  ('ROSE PARK', 0),
#  ('RIDGEHAVEN', 0),
#  ('RENMARK', 0),
#  ('REEVES PLAINS', 0),
#  ('QUEENSTOWN', 0),
#  ('PORT WILLUNGA', 0),
#  ('PORT PIRIE WEST', 0),
#  ('PORT PIRIE', 0),
#  ('POINT PASS', 0),
#  ('PIKE RIVER', 0),
#  ('PAYNEHAM SOUTH', 0),
#  ('PARILLA', 0),
#  ('PANORAMA', 0),
#  ('PAECHTOWN', 0),
#  ('PADTHAWAY', 0),
#  ('OLARY', 0),
#  ('NORTON SUMMIT', 0),
#  ('NORTHGATE', 0),
#  ('NORTH MOONTA', 0),
#  ('NORTH BRIGHTON', 0),
#  ('NEW PORT', 0),
#  ('MYRTLE BANK', 0),
#  ('MURRAY BRIDGE SOUTH', 0),
#  ('MOUNT TORRENS', 0),
#  ('MOSQUITO HILL', 0),
#  ('MOORAK', 0),
#  ('MOONTA BAY', 0),
#  ('MONTEITH', 0),
#  ('MONBULLA', 0),
#  ('MONARTO', 0),
#  ('MILLSWOOD', 0),
#  ('MERRITON', 0),
#  ('MEDINDIE GARDENS', 0),
#  ('MCCRACKEN', 0),
#  ('MANSFIELD PARK', 0),
#  ('MANNINGHAM', 0),
#  ('MALVERN', 0),
#  ('LYRUP', 0),
#  ('LYNTON', 0),
#  ('LOXTON NORTH', 0),
#  ('LOWER MITCHAM', 0),
#  ('LOBETHAL', 0),
#  ('LINCOLN NATIONAL PARK', 0),
#  ('LIGHTSVIEW', 0),
#  ('LENSWOOD', 0),
#  ('KOONAMORE', 0),
#  ('KINGSCOTE', 0),
#  ('KINGS PARK', 0),
#  ('KILKENNY', 0),
#  ('KENSINGTON GARDENS', 0),
#  ('KALBEEBA', 0),
#  ('KAINTON', 0),
#  ('JOSLIN', 0),
#  ('JERICHO', 0),
#  ('IRONBANK', 0),
#  ('INGLEWOOD', 0),
#  ('HYDE PARK', 0),
#  ('HOSKIN CORNER', 0),
#  ('HORSNELL GULLY', 0),
#  ('HOPE VALLEY', 0),
#  ('HILLCREST', 0),
#  ('HIGHGATE', 0),
#  ('HENDON', 0),
#  ('HECTORVILLE', 0),
#  ('HEATHPOOL', 0),
#  ('HAWTHORNDENE', 0),
#  ('HAWKER', 0),
#  ('HAMPSTEAD GARDENS', 0),
#  ('HALLETT', 0),
#  ('GULFVIEW HEIGHTS', 0),
#  ('GREENHILL', 0),
#  ('GOULD CREEK', 0),
#  ('GOOLWA SOUTH', 0),
#  ('GOMERSAL', 0),
#  ('GLENUNGA', 0),
#  ('GLADSTONE', 0),
#  ('GAWLER BELT', 0),
#  ('FULLARTON', 0),
#  ('FULHAM', 0),
#  ('FREWVILLE', 0),
#  ('FARRELL FLAT', 0),
#  ('FAIRVIEW PARK', 0),
#  ('EVANSTON SOUTH', 0),
#  ('DULWICH', 0),
#  ('DUDLEY PARK', 0),
#  ('DAW PARK', 0),
#  ('CUMMINS', 0),
#  ('CUMBERLAND PARK', 0),
#  ('CRYSTAL BROOK', 0),
#  ('COONDAMBO', 0),
#  ('CONDOWIE', 0),
#  ('COMPTON', 0),
#  ('COLONEL LIGHT GARDENS', 0),
#  ('COCKATOO VALLEY', 0),
#  ('CLEARVIEW', 0),
#  ('CLARENDON', 0),
#  ('CLARENCE PARK', 0),
#  ('CLARE', 0),
#  ('CALOOTE', 0),
#  ('CALOMBA', 0),
#  ('BUTE', 0),
#  ('BURR WELL', 0),
#  ('BROWNLOW', 0),
#  ('BROWN HILL CREEK', 0),
#  ('BRINKLEY', 0),
#  ('BORRIKA', 0),
#  ('BOLTO', 0),
#  ('BIRDWOOD', 0),
#  ('BASKET RANGE', 0),
#  ('BARMERA', 0),
#  ('ATHELSTONE', 0),
#  ('ASHTON', 0),
#  ('ARDROSSAN', 0),
#  ('ANNA CREEK', 0),
#  ('ANGLE PARK', 0),
#  ('ANDREWS', 0),
#  ('ANANGU PITJANTJATJARA YANKUNYTJATJARA', 0),
#  ('ALMA', 0)]

# %% [markdown]
# ### DataFrame

# %%
# %%time
# Log the time taken for the query

# Filter the units DF to only the unlicenced drivers
df_units_unlicenced = df_units.filter(f.col('Licence Type') == 'Unlicenced')

# Join both the DFs on REPORT_ID
df_joined = df_units_unlicenced.join(df_crash,
                                     df_units_unlicenced.REPORT_ID == df_crash.REPORT_ID,
                                     how = 'inner')

# Group by suburb, aggregate the sum of casualties accordingly and sort them based on the total sum for easy comparison
df_joined = df_joined.groupBy('Suburb').agg({'Total Cas': 'sum'}).sort('sum(Total Cas)', ascending = False)\
                    .withColumnRenamed('sum(Total Cas)', 'Total Casualties') # Rename the column as required

# Print the total number of rows in the result
print('Total rows: ', df_joined.count())
# Show the result DF
df_joined.show()
# Out:
# Total rows:  634
# +---------------+----------------+
# |         Suburb|Total Casualties|
# +---------------+----------------+
# |       ADELAIDE|              19|
# |      SALISBURY|              18|
# |      DRY CREEK|              18|
# | SALISBURY EAST|              16|
# |       PROSPECT|              14|
# | NORTH ADELAIDE|              13|
# |        ENFIELD|              12|
# |   ANDREWS FARM|              12|
# |SALISBURY SOUTH|              11|
# |   BEDFORD PARK|              11|
# |     INGLE FARM|              11|
# |SALISBURY DOWNS|              11|
# |   MOUNT BARKER|              10|
# |     MUNNO PARA|              10|
# |SALISBURY PLAIN|              10|
# | ELIZABETH PARK|              10|
# |         BURTON|              10|
# |  MORPHETT VALE|              10|
# |   MAWSON LAKES|              10|
# | ELIZABETH EAST|               9|
# +---------------+----------------+
# only showing top 20 rows
#
# CPU times: user 1.66 ms, sys: 4.23 ms, total: 5.89 ms
# Wall time: 3.43 s

# %% [markdown]
# ### Spark SQL

# %%
# %%time
# Log the time taken for the query

# Write the SQL query for retreiving the required result and store it
sql_query = spark.sql('''
  SELECT
      c.Suburb,
      sum(c.`Total Cas`) AS `Total Casualties`
  FROM sql_units u
  JOIN sql_crash c ON u.REPORT_ID = c.REPORT_ID
  WHERE u.`Licence Type` = 'Unlicenced'
  GROUP BY c.Suburb
  ORDER BY sum(c.`Total Cas`) DESC, c.Suburb DESC
''')

# Print the total number of rows in the result
print('Total rows: ', sql_query.count())
# Show the result of the SQL query
sql_query.show()
# Out:
# Total rows:  634
# +---------------+----------------+
# |         Suburb|Total Casualties|
# +---------------+----------------+
# |       ADELAIDE|              19|
# |      SALISBURY|              18|
# |      DRY CREEK|              18|
# | SALISBURY EAST|              16|
# |       PROSPECT|              14|
# | NORTH ADELAIDE|              13|
# |        ENFIELD|              12|
# |   ANDREWS FARM|              12|
# |SALISBURY SOUTH|              11|
# |SALISBURY DOWNS|              11|
# |     INGLE FARM|              11|
# |   BEDFORD PARK|              11|
# |SALISBURY PLAIN|              10|
# |     MUNNO PARA|              10|
# |   MOUNT BARKER|              10|
# |  MORPHETT VALE|              10|
# |   MAWSON LAKES|              10|
# | ELIZABETH PARK|              10|
# |         BURTON|              10|
# |SALISBURY NORTH|               9|
# +---------------+----------------+
# only showing top 20 rows
#
# CPU times: user 3.83 ms, sys: 93 µs, total: 3.93 ms
# Wall time: 3.41 s

# %% [markdown]
# ### End of the assignment
